# %%
import os
import re
import csv
import glob
import random
from pathlib import Path
from tabulate import tabulate
from PIL import Image, ImageOps

import clip 
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader

# %%
device = "cuda:3" if torch.cuda.is_available() else "cpu"
model, preprocess = clip.load("RN101", device=device, jit=False)

TAXA = [
    ("Salmo salar", "Atlantic salmon", "Actinopterygii", "Salmoniformes", "Salmonidae", "Salmo"),
    ("Oncorhynchus mykiss", "Rainbow trout", "Actinopterygii", "Salmoniformes", "Salmonidae", "Oncorhynchus"),
    ("Gadus morhua", "Atlantic cod", "Actinopterygii", "Gadiformes", "Gadidae", "Gadus"),
    ("Melanogrammus aeglefinus", "Haddock", "Actinopterygii", "Gadiformes", "Gadidae", "Melanogrammus"),
    ("Scomber scombrus", "Atlantic mackerel", "Actinopterygii", "Scombriformes", "Scombridae", "Scomber"),
    ("Thunnus thynnus", "Atlantic bluefin tuna", "Actinopterygii", "Scombriformes", "Scombridae", "Thunnus"),
    ("Coryphaena hippurus", "Mahi-mahi", "Actinopterygii", "Carangiformes", "Coryphaenidae", "Coryphaena"),
    ("Xiphias gladius", "Swordfish", "Actinopterygii", "Xiphiiformes", "Xiphiidae", "Xiphias"),
    ("Clupea harengus", "Atlantic herring", "Actinopterygii", "Clupeiformes", "Clupeidae", "Clupea"),
    ("Sardina pilchardus", "European pilchard", "Actinopterygii", "Clupeiformes", "Clupeidae", "Sardina"),
    ("Engraulis encrasicolus", "European anchovy", "Actinopterygii", "Clupeiformes", "Engraulidae", "Engraulis"),
    ("Amphiprion ocellaris", "Ocellaris clownfish", "Actinopterygii", "Blenniiformes", "Pomacentridae", "Amphiprion"),
    ("Pomacanthus imperator", "Emperor angelfish", "Actinopterygii", "Acanthuriformes", "Pomacanthidae", "Pomacanthus"),
    ("Pterois volitans", "Red lionfish", "Actinopterygii", "Scorpaeniformes", "Scorpaenidae", "Pterois"),
    ("Zebrasoma flavescens", "Yellow tang", "Actinopterygii", "Acanthuriformes", "Acanthuridae", "Zebrasoma"),
    ("Hippocampus kuda", "Common seahorse", "Actinopterygii", "Syngnathiformes", "Syngnathidae", "Hippocampus"),
    ("Betta splendens", "Siamese fighting fish", "Actinopterygii", "Anabantiformes", "Osphronemidae", "Betta"),
    ("Paracheirodon innesi", "Neon tetra", "Actinopterygii", "Characiformes", "Characidae", "Paracheirodon"),
    ("Carassius auratus", "Goldfish", "Actinopterygii", "Cypriniformes", "Cyprinidae", "Carassius"),
    ("Cyprinus carpio", "Common carp", "Actinopterygii", "Cypriniformes", "Cyprinidae", "Cyprinus"),
    ("Poecilia reticulata", "Guppy", "Actinopterygii", "Cyprinodontiformes", "Poeciliidae", "Poecilia"),
    ("Astatotilapia burtoni", "Burton’s mouthbrooder", "Actinopterygii", "Cichliformes", "Cichlidae", "Astatotilapia"),
    ("Oreochromis niloticus", "Nile tilapia", "Actinopterygii", "Cichliformes", "Cichlidae", "Oreochromis"),
    ("Pterophyllum scalare", "Freshwater angelfish", "Actinopterygii", "Cichliformes", "Cichlidae", "Pterophyllum"),
    ("Micropterus salmoides", "Florida bass", "Actinopterygii", "Centrarchiformes", "Centrarchidae", "Micropterus"),
    ("Lepomis macrochirus", "Bluegill sunfish", "Actinopterygii", "Centrarchiformes", "Centrarchidae", "Lepomis"),
    ("Esox lucius", "Northern pike", "Actinopterygii", "Esociformes", "Esocidae", "Esox"),
    ("Ictalurus punctatus", "Channel catfish", "Actinopterygii", "Siluriformes", "Ictaluridae", "Ictalurus"),
    ("Silurus glanis", "Wels catfish", "Actinopterygii", "Siluriformes", "Siluridae", "Silurus"),
    ("Electrophorus electricus", "Electric eel", "Actinopterygii", "Gymnotiformes", "Gymnotidae", "Electrophorus"),
    ("Arapaima gigas", "Arapaima", "Actinopterygii", "Osteoglossiformes", "Arapaimidae", "Arapaima"),
    ("Osteoglossum bicirrhosum", "Silver arowana", "Actinopterygii", "Osteoglossiformes", "Osteoglossidae", "Osteoglossum"),
    ("Anguilla anguilla", "European eel", "Actinopterygii", "Anguilliformes", "Anguillidae", "Anguilla"),
    ("Muraena helena", "Mediterranean moray", "Actinopterygii", "Anguilliformes", "Muraenidae", "Muraena"),
    ("Lophius piscatorius", "Monkfish", "Actinopterygii", "Lophiiformes", "Lophiidae", "Lophius"),
    ("Hippoglossus hippoglossus", "Atlantic halibut", "Actinopterygii", "Pleuronectiformes", "Pleuronectidae", "Hippoglossus"),
    ("Pleuronectes platessa", "European plaice", "Actinopterygii", "Pleuronectiformes", "Pleuronectidae", "Pleuronectes"),
    ("Sphyraena barracuda", "Great barracuda", "Actinopterygii", "Carangiformes", "Sphyraenidae", "Sphyraena"),
    ("Dicentrarchus labrax", "European seabass", "Actinopterygii", "Acanthuriformes", "Moronidae", "Dicentrarchus"),
    ("Lutjanus campechanus", "Northern red snapper", "Actinopterygii", "Acanthuriformes", "Lutjanidae", "Lutjanus"),
    ("Epinephelus itajara", "Goliath grouper", "Actinopterygii", "Perciformes", "Epinephelidae", "Epinephelus"),
    ("Cheilinus undulatus", "Humphead wrasse", "Actinopterygii", "Labriformes", "Labridae", "Cheilinus"),
    ("Gobius niger", "Black goby", "Actinopterygii", "Gobiiformes", "Gobiidae", "Gobius"),
    ("Carcharodon carcharias", "Great white shark", "Chondrichthyes", "Lamniformes", "Lamnidae", "Carcharodon"),
    ("Galeocerdo cuvier", "Tiger shark", "Chondrichthyes", "Carcharhiniformes", "Carcharhinidae", "Galeocerdo"),
    ("Sphyrna lewini", "Scalloped hammerhead", "Chondrichthyes", "Carcharhiniformes", "Sphyrnidae", "Sphyrna"),
    ("Raja clavata", "Thornback ray", "Chondrichthyes", "Rajiformes", "Rajidae", "Raja"),
    ("Mobula birostris", "Giant manta ray", "Chondrichthyes", "Myliobatiformes", "Mobulidae", "Mobula"),
    ("Takifugu rubripes", "Japanese pufferfish", "Actinopterygii", "Tetraodontiformes", "Tetraodontidae", "Takifugu"),
    ("Diodon hystrix", "Porcupinefish", "Actinopterygii", "Tetraodontiformes", "Diodontidae", "Diodon"),]

def make_captions(binom, common, cls, order, family, genus):
    return [
        f"{binom}",
        f"a fish from family {family}",
        f"a fish from order {order}",
        f"a fish from class {cls}",]

def build_clip_lists(root="dataCLIP"):
    root = Path(root)
    image_paths, text_options = [], []
    for species in TAXA:
        binom, common, cls, order, family, genus = species
        captions = make_captions(binom, common, cls, order, family, genus)
        folder_path = root / binom.replace(" ", "_")
        for img in sorted(folder_path.glob("*")):
            if img.suffix.lower() in {".jpg", ".jpeg", ".png", ".webp"}:
                image_paths.append(str(img))
                text_options.append(captions)
    assert len(image_paths) == len(text_options)
    return image_paths, text_options

class CLIP_dataset(Dataset):
    def __init__(self, list_image_path, list_txt_options):
        self.image_path = list_image_path
        self.text_options = list_txt_options

    def __len__(self):
        return len(self.image_path)

    def __getitem__(self, idx):
        img_path = self.image_path[idx]

        caption_list = self.text_options[idx]
        caption = random.choice(caption_list)

        img = Image.open(img_path)
        img = ImageOps.exif_transpose(img)
        if img.mode == "P" and ("transparency" in img.info or img.info.get("transparency") is not None):
            img = img.convert("RGBA").convert("RGB")
        else:
            img = img.convert("RGB")
        img.load()

        image = preprocess(img)
        title = clip.tokenize(caption)[0]
        return image, title

image_data, text_data = build_clip_lists("dataCLIP")
dataset = CLIP_dataset(image_data, text_data)
train_dataloader = DataLoader(dataset, batch_size=16, shuffle=True)

# %%
# Tokenize the text prompts
prompts = ["Salmonidae", "Sphyraenidae",
           "Pomacanthidae", "Epinephelidae",
           "Moronidae", "Gymnotidae"]

text_tokens = clip.tokenize(prompts).to(device)

@torch.no_grad()
def clip_predict(image_path, text_tokens, texts, model, preprocess, device, topk=5):
    # Model evaluation mode
    model.eval()

    # Load and process image
    img = Image.open(image_path)
    image = preprocess(img).unsqueeze(0).to(device)

    # Infer image
    logits_per_image, _ = model(image, text_tokens)        
    probs = logits_per_image.softmax(dim=-1).squeeze(0)            

    # Get top k results
    k = min(topk, len(texts))
    scores, idx = torch.topk(probs, k=k, largest=True, sorted=True)
    return [(float(scores[i]), texts[int(idx[i])]) for i in range(k)]

def run_evaluation(imgFolder):
    # Assert image folder
    if not os.path.exists(imgFolder):
        print(f"{imgFolder} does not exist.")
        return 
    if not len(glob.glob(f"{imgFolder}/*")):
        print(f"{imgFolder} is empty.")
        return 

    # Run evaluation and tabulate
    rows = []
    for name in glob.glob(f"{imgFolder}/*"):
        results = clip_predict(name, text_tokens, prompts, model, preprocess, device, topk=3)
        name_split = os.path.basename(name).split(".")[0].split("_")
        
        row = [f"{name_split[0]} {name_split[1]}"] + [name_split[2]] + [f"{label} ({score:.3f})" for score, label in results]
        rows.append(row)

    headers = ["Image", "True Family", "Top-1", "Top-2", "Top-3"]
    print(tabulate(rows, headers=headers, tablefmt="fancy_grid"), "\n")

run_evaluation("zeroCLIP")
# Out:
# ╒═══════════════════════════╤═══════════════╤════════════════════╤═══════════════════════╤═══════════════════════╕
# │ Image                     │ True Family   │ Top-1              │ Top-2                 │ Top-3                 │
# ╞═══════════════════════════╪═══════════════╪════════════════════╪═══════════════════════╪═══════════════════════╡
# │ Salmo hucho               │ Salmonidae    │ Salmonidae (0.999) │ Moronidae (0.001)     │ Pomacanthidae (0.000) │
# ├───────────────────────────┼───────────────┼────────────────────┼───────────────────────┼───────────────────────┤
# │ Sphyraena novaehollandiae │ Sphyraenidae  │ Salmonidae (0.986) │ Moronidae (0.005)     │ Pomacanthidae (0.004) │
# ├───────────────────────────┼───────────────┼────────────────────┼───────────────────────┼───────────────────────┤
# │ Centropyge boylei         │ Pomacanthidae │ Salmonidae (0.442) │ Pomacanthidae (0.313) │ Moronidae (0.093)     │
# ├───────────────────────────┼───────────────┼────────────────────┼───────────────────────┼───────────────────────┤
# │ Gymnotus carapo           │ Gymnotidae    │ Salmonidae (0.905) │ Sphyraenidae (0.029)  │ Gymnotidae (0.023)    │
# ├───────────────────────────┼───────────────┼────────────────────┼───────────────────────┼───────────────────────┤
# │ Electrophorus electricus  │ Gymnotidae    │ Salmonidae (0.878) │ Moronidae (0.041)     │ Pomacanthidae (0.041) │
# ├───────────────────────────┼───────────────┼────────────────────┼───────────────────────┼───────────────────────┤
# │ Morone americana          │ Moronidae     │ Salmonidae (0.419) │ Pomacanthidae (0.279) │ Sphyraenidae (0.149)  │
# ╘═══════════════════════════╧═══════════════╧════════════════════╧═══════════════════════╧═══════════════════════╛

# %%
model = model.float().to(device)

loss_img = nn.CrossEntropyLoss()
loss_txt = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=5e-6,betas=(0.9,0.98),eps=1e-6,weight_decay=0.001)
EPOCH = 25

for epoch in range(EPOCH):
    model.train()
    epoch_loss_sum = 0.0
    epoch_count = 0
    step_idx = 0
    print (15*"-", f"Epoch {epoch+1}", 15*"-")
    for batch in train_dataloader:
        optimizer.zero_grad()

        images, texts = batch
        images = images.to(device)
        texts  = texts.to(device)

        logits_per_image, logits_per_text = model(images, texts)
        logits_per_image = logits_per_image.contiguous()
        logits_per_text  = logits_per_text.contiguous()
        
        ground_truth = torch.arange(len(images), dtype=torch.long, device=device)
        total_loss = (loss_img(logits_per_image, ground_truth) + loss_txt(logits_per_text, ground_truth)) / 2

        total_loss.backward()
        optimizer.step()

        bs = images.size(0)
        epoch_loss_sum += float(total_loss.detach()) * bs
        epoch_count += bs
        
        step_idx += 1
        if step_idx % 10 == 0:
            running_avg = epoch_loss_sum / max(1, epoch_count)
            print(f"Epoch {epoch+1} | Step {step_idx}/{len(train_dataloader)} | Running average step loss: {running_avg:.4f}")
    epoch_avg = epoch_loss_sum / max(1, epoch_count)
    print(f"Epoch {epoch+1} | Epoch average loss: {epoch_avg:.4f}\n")
    run_evaluation("zeroCLIP")
# Out:
# --------------- Epoch 1 ---------------
# Epoch 1 | Step 10/79 | Running average step loss: 3.5526
# Epoch 1 | Step 20/79 | Running average step loss: 3.2833
# Epoch 1 | Step 30/79 | Running average step loss: 3.1651
# Epoch 1 | Step 40/79 | Running average step loss: 3.0949
# Epoch 1 | Step 50/79 | Running average step loss: 3.0095
# Epoch 1 | Step 60/79 | Running average step loss: 2.9676
# Epoch 1 | Step 70/79 | Running average step loss: 2.9173
# Epoch 1 | Epoch average loss: 2.8797
#
# ╒═══════════════════════════╤═══════════════╤═══════════════════════╤═══════════════════════╤══════════════════════╕
# │ Image                     │ True Family   │ Top-1                 │ Top-2                 │ Top-3                │
# ╞═══════════════════════════╪═══════════════╪═══════════════════════╪═══════════════════════╪══════════════════════╡
# │ Salmo hucho               │ Salmonidae    │ Salmonidae (0.283)    │ Epinephelidae (0.177) │ Moronidae (0.160)    │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼──────────────────────┤
# │ Sphyraena novaehollandiae │ Sphyraenidae  │ Epinephelidae (0.230) │ Pomacanthidae (0.217) │ Salmonidae (0.194)   │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼──────────────────────┤
# │ Centropyge boylei         │ Pomacanthidae │ Sphyraenidae (0.185)  │ Pomacanthidae (0.184) │ Salmonidae (0.172)   │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼──────────────────────┤
# │ Gymnotus carapo           │ Gymnotidae    │ Salmonidae (0.217)    │ Pomacanthidae (0.183) │ Sphyraenidae (0.174) │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼──────────────────────┤
# │ Electrophorus electricus  │ Gymnotidae    │ Salmonidae (0.263)    │ Gymnotidae (0.236)    │ Sphyraenidae (0.156) │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼──────────────────────┤
# │ Morone americana          │ Moronidae     │ Sphyraenidae (0.258)  │ Salmonidae (0.185)    │ Gymnotidae (0.179)   │
# ╘═══════════════════════════╧═══════════════╧═══════════════════════╧═══════════════════════╧══════════════════════╛
#
# --------------- Epoch 2 ---------------
# Epoch 2 | Step 10/79 | Running average step loss: 2.4315
# Epoch 2 | Step 20/79 | Running average step loss: 2.3912
# Epoch 2 | Step 30/79 | Running average step loss: 2.3353
# Epoch 2 | Step 40/79 | Running average step loss: 2.3223
# Epoch 2 | Step 50/79 | Running average step loss: 2.3086
# Epoch 2 | Step 60/79 | Running average step loss: 2.2796
# Epoch 2 | Step 70/79 | Running average step loss: 2.2672
# Epoch 2 | Epoch average loss: 2.2398
#
# ╒═══════════════════════════╤═══════════════╤═══════════════════════╤═══════════════════════╤════════════════════╕
# │ Image                     │ True Family   │ Top-1                 │ Top-2                 │ Top-3              │
# ╞═══════════════════════════╪═══════════════╪═══════════════════════╪═══════════════════════╪════════════════════╡
# │ Salmo hucho               │ Salmonidae    │ Salmonidae (0.667)    │ Epinephelidae (0.176) │ Moronidae (0.071)  │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼────────────────────┤
# │ Sphyraena novaehollandiae │ Sphyraenidae  │ Epinephelidae (0.341) │ Sphyraenidae (0.311)  │ Salmonidae (0.181) │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼────────────────────┤
# │ Centropyge boylei         │ Pomacanthidae │ Pomacanthidae (0.373) │ Gymnotidae (0.195)    │ Salmonidae (0.193) │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼────────────────────┤
# │ Gymnotus carapo           │ Gymnotidae    │ Moronidae (0.380)     │ Salmonidae (0.227)    │ Gymnotidae (0.155) │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼────────────────────┤
# │ Electrophorus electricus  │ Gymnotidae    │ Gymnotidae (0.288)    │ Sphyraenidae (0.286)  │ Moronidae (0.177)  │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼────────────────────┤
# │ Morone americana          │ Moronidae     │ Gymnotidae (0.385)    │ Moronidae (0.295)     │ Salmonidae (0.099) │
# ╘═══════════════════════════╧═══════════════╧═══════════════════════╧═══════════════════════╧════════════════════╛
#
# --------------- Epoch 3 ---------------
# Epoch 3 | Step 10/79 | Running average step loss: 1.9695
# Epoch 3 | Step 20/79 | Running average step loss: 1.8632
# Epoch 3 | Step 30/79 | Running average step loss: 1.8584
# Epoch 3 | Step 40/79 | Running average step loss: 1.9001
# Epoch 3 | Step 50/79 | Running average step loss: 1.8867
# Epoch 3 | Step 60/79 | Running average step loss: 1.8844
# Epoch 3 | Step 70/79 | Running average step loss: 1.8750
# Epoch 3 | Epoch average loss: 1.8678
#
# ╒═══════════════════════════╤═══════════════╤═══════════════════════╤═══════════════════════╤═══════════════════════╕
# │ Image                     │ True Family   │ Top-1                 │ Top-2                 │ Top-3                 │
# ╞═══════════════════════════╪═══════════════╪═══════════════════════╪═══════════════════════╪═══════════════════════╡
# │ Salmo hucho               │ Salmonidae    │ Salmonidae (0.860)    │ Epinephelidae (0.072) │ Gymnotidae (0.040)    │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Sphyraena novaehollandiae │ Sphyraenidae  │ Gymnotidae (0.338)    │ Epinephelidae (0.225) │ Salmonidae (0.151)    │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Centropyge boylei         │ Pomacanthidae │ Pomacanthidae (0.568) │ Salmonidae (0.164)    │ Gymnotidae (0.148)    │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Gymnotus carapo           │ Gymnotidae    │ Salmonidae (0.787)    │ Gymnotidae (0.143)    │ Epinephelidae (0.036) │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Electrophorus electricus  │ Gymnotidae    │ Gymnotidae (0.712)    │ Sphyraenidae (0.101)  │ Salmonidae (0.090)    │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Morone americana          │ Moronidae     │ Moronidae (0.475)     │ Gymnotidae (0.223)    │ Epinephelidae (0.204) │
# ╘═══════════════════════════╧═══════════════╧═══════════════════════╧═══════════════════════╧═══════════════════════╛
#
# --------------- Epoch 4 ---------------
# Epoch 4 | Step 10/79 | Running average step loss: 1.7412
# Epoch 4 | Step 20/79 | Running average step loss: 1.6866
# Epoch 4 | Step 30/79 | Running average step loss: 1.6762
# Epoch 4 | Step 40/79 | Running average step loss: 1.6938
# Epoch 4 | Step 50/79 | Running average step loss: 1.6619
# Epoch 4 | Step 60/79 | Running average step loss: 1.6424
# Epoch 4 | Step 70/79 | Running average step loss: 1.6280
# Epoch 4 | Epoch average loss: 1.6231
#
# ╒═══════════════════════════╤═══════════════╤═══════════════════════╤══════════════════════╤═══════════════════════╕
# │ Image                     │ True Family   │ Top-1                 │ Top-2                │ Top-3                 │
# ╞═══════════════════════════╪═══════════════╪═══════════════════════╪══════════════════════╪═══════════════════════╡
# │ Salmo hucho               │ Salmonidae    │ Salmonidae (0.747)    │ Gymnotidae (0.099)   │ Epinephelidae (0.087) │
# ├───────────────────────────┼───────────────┼───────────────────────┼──────────────────────┼───────────────────────┤
# │ Sphyraena novaehollandiae │ Sphyraenidae  │ Sphyraenidae (0.498)  │ Gymnotidae (0.330)   │ Salmonidae (0.097)    │
# ├───────────────────────────┼───────────────┼───────────────────────┼──────────────────────┼───────────────────────┤
# │ Centropyge boylei         │ Pomacanthidae │ Pomacanthidae (0.408) │ Sphyraenidae (0.281) │ Salmonidae (0.176)    │
# ├───────────────────────────┼───────────────┼───────────────────────┼──────────────────────┼───────────────────────┤
# │ Gymnotus carapo           │ Gymnotidae    │ Gymnotidae (0.465)    │ Salmonidae (0.265)   │ Epinephelidae (0.247) │
# ├───────────────────────────┼───────────────┼───────────────────────┼──────────────────────┼───────────────────────┤
# │ Electrophorus electricus  │ Gymnotidae    │ Gymnotidae (0.899)    │ Moronidae (0.031)    │ Sphyraenidae (0.025)  │
# ├───────────────────────────┼───────────────┼───────────────────────┼──────────────────────┼───────────────────────┤
# │ Morone americana          │ Moronidae     │ Moronidae (0.424)     │ Gymnotidae (0.238)   │ Salmonidae (0.220)    │
# ╘═══════════════════════════╧═══════════════╧═══════════════════════╧══════════════════════╧═══════════════════════╛
#
# --------------- Epoch 5 ---------------
# Epoch 5 | Step 10/79 | Running average step loss: 1.5251
# Epoch 5 | Step 20/79 | Running average step loss: 1.4519
# Epoch 5 | Step 30/79 | Running average step loss: 1.4455
# Epoch 5 | Step 40/79 | Running average step loss: 1.4369
# Epoch 5 | Step 50/79 | Running average step loss: 1.4655
# Epoch 5 | Step 60/79 | Running average step loss: 1.4140
# Epoch 5 | Step 70/79 | Running average step loss: 1.4111
# Epoch 5 | Epoch average loss: 1.3937
#
# ╒═══════════════════════════╤═══════════════╤═══════════════════════╤═══════════════════════╤═══════════════════════╕
# │ Image                     │ True Family   │ Top-1                 │ Top-2                 │ Top-3                 │
# ╞═══════════════════════════╪═══════════════╪═══════════════════════╪═══════════════════════╪═══════════════════════╡
# │ Salmo hucho               │ Salmonidae    │ Salmonidae (0.571)    │ Epinephelidae (0.316) │ Moronidae (0.041)     │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Sphyraena novaehollandiae │ Sphyraenidae  │ Sphyraenidae (0.816)  │ Gymnotidae (0.080)    │ Epinephelidae (0.065) │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Centropyge boylei         │ Pomacanthidae │ Pomacanthidae (0.681) │ Sphyraenidae (0.135)  │ Gymnotidae (0.114)    │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Gymnotus carapo           │ Gymnotidae    │ Salmonidae (0.748)    │ Epinephelidae (0.122) │ Gymnotidae (0.117)    │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Electrophorus electricus  │ Gymnotidae    │ Gymnotidae (0.884)    │ Moronidae (0.048)     │ Epinephelidae (0.030) │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Morone americana          │ Moronidae     │ Moronidae (0.888)     │ Epinephelidae (0.049) │ Gymnotidae (0.048)    │
# ╘═══════════════════════════╧═══════════════╧═══════════════════════╧═══════════════════════╧═══════════════════════╛
#
# --------------- Epoch 6 ---------------
# Epoch 6 | Step 10/79 | Running average step loss: 1.3623
# Epoch 6 | Step 20/79 | Running average step loss: 1.3890
# Epoch 6 | Step 30/79 | Running average step loss: 1.4295
# Epoch 6 | Step 40/79 | Running average step loss: 1.3763
# Epoch 6 | Step 50/79 | Running average step loss: 1.3985
# Epoch 6 | Step 60/79 | Running average step loss: 1.3613
# Epoch 6 | Step 70/79 | Running average step loss: 1.3353
# Epoch 6 | Epoch average loss: 1.3217
#
# ╒═══════════════════════════╤═══════════════╤═══════════════════════╤═══════════════════════╤═══════════════════════╕
# │ Image                     │ True Family   │ Top-1                 │ Top-2                 │ Top-3                 │
# ╞═══════════════════════════╪═══════════════╪═══════════════════════╪═══════════════════════╪═══════════════════════╡
# │ Salmo hucho               │ Salmonidae    │ Salmonidae (0.856)    │ Epinephelidae (0.074) │ Sphyraenidae (0.037)  │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Sphyraena novaehollandiae │ Sphyraenidae  │ Sphyraenidae (0.654)  │ Epinephelidae (0.165) │ Salmonidae (0.132)    │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Centropyge boylei         │ Pomacanthidae │ Pomacanthidae (0.482) │ Sphyraenidae (0.296)  │ Gymnotidae (0.126)    │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Gymnotus carapo           │ Gymnotidae    │ Salmonidae (0.908)    │ Gymnotidae (0.042)    │ Epinephelidae (0.036) │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Electrophorus electricus  │ Gymnotidae    │ Gymnotidae (0.878)    │ Sphyraenidae (0.075)  │ Epinephelidae (0.031) │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Morone americana          │ Moronidae     │ Moronidae (0.930)     │ Gymnotidae (0.027)    │ Epinephelidae (0.026) │
# ╘═══════════════════════════╧═══════════════╧═══════════════════════╧═══════════════════════╧═══════════════════════╛
#
# --------------- Epoch 7 ---------------
# Epoch 7 | Step 10/79 | Running average step loss: 1.4012
# Epoch 7 | Step 20/79 | Running average step loss: 1.4212
# Epoch 7 | Step 30/79 | Running average step loss: 1.3830
# Epoch 7 | Step 40/79 | Running average step loss: 1.3272
# Epoch 7 | Step 50/79 | Running average step loss: 1.3246
# Epoch 7 | Step 60/79 | Running average step loss: 1.3166
# Epoch 7 | Step 70/79 | Running average step loss: 1.3137
# Epoch 7 | Epoch average loss: 1.3115
#
# ╒═══════════════════════════╤═══════════════╤═══════════════════════╤═══════════════════════╤═══════════════════════╕
# │ Image                     │ True Family   │ Top-1                 │ Top-2                 │ Top-3                 │
# ╞═══════════════════════════╪═══════════════╪═══════════════════════╪═══════════════════════╪═══════════════════════╡
# │ Salmo hucho               │ Salmonidae    │ Salmonidae (0.964)    │ Sphyraenidae (0.015)  │ Gymnotidae (0.011)    │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Sphyraena novaehollandiae │ Sphyraenidae  │ Sphyraenidae (0.907)  │ Gymnotidae (0.038)    │ Epinephelidae (0.034) │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Centropyge boylei         │ Pomacanthidae │ Pomacanthidae (0.507) │ Sphyraenidae (0.206)  │ Gymnotidae (0.170)    │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Gymnotus carapo           │ Gymnotidae    │ Salmonidae (0.594)    │ Gymnotidae (0.342)    │ Epinephelidae (0.038) │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Electrophorus electricus  │ Gymnotidae    │ Gymnotidae (0.939)    │ Epinephelidae (0.039) │ Sphyraenidae (0.013)  │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Morone americana          │ Moronidae     │ Moronidae (0.815)     │ Salmonidae (0.076)    │ Gymnotidae (0.043)    │
# ╘═══════════════════════════╧═══════════════╧═══════════════════════╧═══════════════════════╧═══════════════════════╛
#
# --------------- Epoch 8 ---------------
# Epoch 8 | Step 10/79 | Running average step loss: 1.2468
# Epoch 8 | Step 20/79 | Running average step loss: 1.2304
# Epoch 8 | Step 30/79 | Running average step loss: 1.2356
# Epoch 8 | Step 40/79 | Running average step loss: 1.2366
# Epoch 8 | Step 50/79 | Running average step loss: 1.2301
# Epoch 8 | Step 60/79 | Running average step loss: 1.2109
# Epoch 8 | Step 70/79 | Running average step loss: 1.2295
# Epoch 8 | Epoch average loss: 1.2328
#
# ╒═══════════════════════════╤═══════════════╤═══════════════════════╤═══════════════════════╤═══════════════════════╕
# │ Image                     │ True Family   │ Top-1                 │ Top-2                 │ Top-3                 │
# ╞═══════════════════════════╪═══════════════╪═══════════════════════╪═══════════════════════╪═══════════════════════╡
# │ Salmo hucho               │ Salmonidae    │ Salmonidae (0.977)    │ Epinephelidae (0.012) │ Gymnotidae (0.006)    │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Sphyraena novaehollandiae │ Sphyraenidae  │ Sphyraenidae (0.975)  │ Epinephelidae (0.009) │ Salmonidae (0.009)    │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Centropyge boylei         │ Pomacanthidae │ Pomacanthidae (0.914) │ Gymnotidae (0.040)    │ Salmonidae (0.023)    │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Gymnotus carapo           │ Gymnotidae    │ Gymnotidae (0.537)    │ Salmonidae (0.348)    │ Epinephelidae (0.111) │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Electrophorus electricus  │ Gymnotidae    │ Gymnotidae (0.998)    │ Epinephelidae (0.001) │ Sphyraenidae (0.001)  │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Morone americana          │ Moronidae     │ Moronidae (0.935)     │ Epinephelidae (0.029) │ Salmonidae (0.016)    │
# ╘═══════════════════════════╧═══════════════╧═══════════════════════╧═══════════════════════╧═══════════════════════╛
#
# --------------- Epoch 9 ---------------
# Epoch 9 | Step 10/79 | Running average step loss: 1.2052
# Epoch 9 | Step 20/79 | Running average step loss: 1.3226
# Epoch 9 | Step 30/79 | Running average step loss: 1.2305
# Epoch 9 | Step 40/79 | Running average step loss: 1.2199
# Epoch 9 | Step 50/79 | Running average step loss: 1.2210
# Epoch 9 | Step 60/79 | Running average step loss: 1.2253
# Epoch 9 | Step 70/79 | Running average step loss: 1.2078
# Epoch 9 | Epoch average loss: 1.2088
#
# ╒═══════════════════════════╤═══════════════╤═══════════════════════╤═══════════════════════╤═══════════════════════╕
# │ Image                     │ True Family   │ Top-1                 │ Top-2                 │ Top-3                 │
# ╞═══════════════════════════╪═══════════════╪═══════════════════════╪═══════════════════════╪═══════════════════════╡
# │ Salmo hucho               │ Salmonidae    │ Salmonidae (0.850)    │ Epinephelidae (0.105) │ Sphyraenidae (0.027)  │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Sphyraena novaehollandiae │ Sphyraenidae  │ Sphyraenidae (0.997)  │ Gymnotidae (0.001)    │ Salmonidae (0.001)    │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Centropyge boylei         │ Pomacanthidae │ Pomacanthidae (0.751) │ Gymnotidae (0.178)    │ Salmonidae (0.039)    │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Gymnotus carapo           │ Gymnotidae    │ Gymnotidae (0.510)    │ Salmonidae (0.351)    │ Epinephelidae (0.134) │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Electrophorus electricus  │ Gymnotidae    │ Gymnotidae (0.927)    │ Sphyraenidae (0.065)  │ Epinephelidae (0.006) │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Morone americana          │ Moronidae     │ Epinephelidae (0.513) │ Moronidae (0.431)     │ Gymnotidae (0.027)    │
# ╘═══════════════════════════╧═══════════════╧═══════════════════════╧═══════════════════════╧═══════════════════════╛
#
# --------------- Epoch 10 ---------------
# Epoch 10 | Step 10/79 | Running average step loss: 1.3714
# Epoch 10 | Step 20/79 | Running average step loss: 1.2010
# Epoch 10 | Step 30/79 | Running average step loss: 1.1689
# Epoch 10 | Step 40/79 | Running average step loss: 1.1374
# Epoch 10 | Step 50/79 | Running average step loss: 1.1461
# Epoch 10 | Step 60/79 | Running average step loss: 1.1274
# Epoch 10 | Step 70/79 | Running average step loss: 1.1330
# Epoch 10 | Epoch average loss: 1.1383
#
# ╒═══════════════════════════╤═══════════════╤═══════════════════════╤══════════════════════╤═══════════════════════╕
# │ Image                     │ True Family   │ Top-1                 │ Top-2                │ Top-3                 │
# ╞═══════════════════════════╪═══════════════╪═══════════════════════╪══════════════════════╪═══════════════════════╡
# │ Salmo hucho               │ Salmonidae    │ Salmonidae (0.523)    │ Gymnotidae (0.283)   │ Epinephelidae (0.165) │
# ├───────────────────────────┼───────────────┼───────────────────────┼──────────────────────┼───────────────────────┤
# │ Sphyraena novaehollandiae │ Sphyraenidae  │ Sphyraenidae (0.998)  │ Gymnotidae (0.001)   │ Epinephelidae (0.000) │
# ├───────────────────────────┼───────────────┼───────────────────────┼──────────────────────┼───────────────────────┤
# │ Centropyge boylei         │ Pomacanthidae │ Pomacanthidae (0.903) │ Gymnotidae (0.063)   │ Salmonidae (0.027)    │
# ├───────────────────────────┼───────────────┼───────────────────────┼──────────────────────┼───────────────────────┤
# │ Gymnotus carapo           │ Gymnotidae    │ Gymnotidae (0.373)    │ Salmonidae (0.349)   │ Epinephelidae (0.269) │
# ├───────────────────────────┼───────────────┼───────────────────────┼──────────────────────┼───────────────────────┤
# │ Electrophorus electricus  │ Gymnotidae    │ Gymnotidae (0.963)    │ Sphyraenidae (0.022) │ Salmonidae (0.010)    │
# ├───────────────────────────┼───────────────┼───────────────────────┼──────────────────────┼───────────────────────┤
# │ Morone americana          │ Moronidae     │ Moronidae (0.757)     │ Gymnotidae (0.133)   │ Epinephelidae (0.084) │
# ╘═══════════════════════════╧═══════════════╧═══════════════════════╧══════════════════════╧═══════════════════════╛
#
# --------------- Epoch 11 ---------------
# Epoch 11 | Step 10/79 | Running average step loss: 1.2192
# Epoch 11 | Step 20/79 | Running average step loss: 1.1206
# Epoch 11 | Step 30/79 | Running average step loss: 1.1419
# Epoch 11 | Step 40/79 | Running average step loss: 1.1344
# Epoch 11 | Step 50/79 | Running average step loss: 1.1243
# Epoch 11 | Step 60/79 | Running average step loss: 1.0952
# Epoch 11 | Step 70/79 | Running average step loss: 1.0941
# Epoch 11 | Epoch average loss: 1.0819
#
# ╒═══════════════════════════╤═══════════════╤═══════════════════════╤═══════════════════════╤═══════════════════════╕
# │ Image                     │ True Family   │ Top-1                 │ Top-2                 │ Top-3                 │
# ╞═══════════════════════════╪═══════════════╪═══════════════════════╪═══════════════════════╪═══════════════════════╡
# │ Salmo hucho               │ Salmonidae    │ Salmonidae (0.998)    │ Gymnotidae (0.001)    │ Sphyraenidae (0.000)  │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Sphyraena novaehollandiae │ Sphyraenidae  │ Sphyraenidae (0.997)  │ Salmonidae (0.002)    │ Gymnotidae (0.001)    │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Centropyge boylei         │ Pomacanthidae │ Pomacanthidae (0.985) │ Gymnotidae (0.007)    │ Sphyraenidae (0.004)  │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Gymnotus carapo           │ Gymnotidae    │ Epinephelidae (0.560) │ Salmonidae (0.220)    │ Gymnotidae (0.217)    │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Electrophorus electricus  │ Gymnotidae    │ Gymnotidae (0.848)    │ Sphyraenidae (0.116)  │ Epinephelidae (0.014) │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Morone americana          │ Moronidae     │ Moronidae (0.825)     │ Epinephelidae (0.141) │ Salmonidae (0.013)    │
# ╘═══════════════════════════╧═══════════════╧═══════════════════════╧═══════════════════════╧═══════════════════════╛
#
# --------------- Epoch 12 ---------------
# Epoch 12 | Step 10/79 | Running average step loss: 1.1857
# Epoch 12 | Step 20/79 | Running average step loss: 1.2113
# Epoch 12 | Step 30/79 | Running average step loss: 1.2016
# Epoch 12 | Step 40/79 | Running average step loss: 1.2049
# Epoch 12 | Step 50/79 | Running average step loss: 1.2059
# Epoch 12 | Step 60/79 | Running average step loss: 1.1941
# Epoch 12 | Step 70/79 | Running average step loss: 1.1868
# Epoch 12 | Epoch average loss: 1.1777
#
# ╒═══════════════════════════╤═══════════════╤═══════════════════════╤═══════════════════════╤═══════════════════════╕
# │ Image                     │ True Family   │ Top-1                 │ Top-2                 │ Top-3                 │
# ╞═══════════════════════════╪═══════════════╪═══════════════════════╪═══════════════════════╪═══════════════════════╡
# │ Salmo hucho               │ Salmonidae    │ Salmonidae (0.998)    │ Gymnotidae (0.001)    │ Moronidae (0.001)     │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Sphyraena novaehollandiae │ Sphyraenidae  │ Sphyraenidae (0.999)  │ Salmonidae (0.001)    │ Gymnotidae (0.001)    │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Centropyge boylei         │ Pomacanthidae │ Pomacanthidae (0.778) │ Gymnotidae (0.173)    │ Salmonidae (0.020)    │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Gymnotus carapo           │ Gymnotidae    │ Salmonidae (0.502)    │ Gymnotidae (0.258)    │ Epinephelidae (0.239) │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Electrophorus electricus  │ Gymnotidae    │ Gymnotidae (0.981)    │ Sphyraenidae (0.014)  │ Epinephelidae (0.002) │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Morone americana          │ Moronidae     │ Moronidae (0.987)     │ Epinephelidae (0.005) │ Salmonidae (0.005)    │
# ╘═══════════════════════════╧═══════════════╧═══════════════════════╧═══════════════════════╧═══════════════════════╛
#
# --------------- Epoch 13 ---------------
# Epoch 13 | Step 10/79 | Running average step loss: 1.1285
# Epoch 13 | Step 20/79 | Running average step loss: 1.1248
# Epoch 13 | Step 30/79 | Running average step loss: 1.0918
# Epoch 13 | Step 40/79 | Running average step loss: 1.0481
# Epoch 13 | Step 50/79 | Running average step loss: 1.0179
# Epoch 13 | Step 60/79 | Running average step loss: 0.9931
# Epoch 13 | Step 70/79 | Running average step loss: 1.0247
# Epoch 13 | Epoch average loss: 1.0117
#
# ╒═══════════════════════════╤═══════════════╤═══════════════════════╤═══════════════════════╤════════════════════╕
# │ Image                     │ True Family   │ Top-1                 │ Top-2                 │ Top-3              │
# ╞═══════════════════════════╪═══════════════╪═══════════════════════╪═══════════════════════╪════════════════════╡
# │ Salmo hucho               │ Salmonidae    │ Salmonidae (0.994)    │ Moronidae (0.002)     │ Gymnotidae (0.002) │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼────────────────────┤
# │ Sphyraena novaehollandiae │ Sphyraenidae  │ Sphyraenidae (0.999)  │ Epinephelidae (0.001) │ Salmonidae (0.000) │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼────────────────────┤
# │ Centropyge boylei         │ Pomacanthidae │ Pomacanthidae (0.980) │ Gymnotidae (0.010)    │ Salmonidae (0.006) │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼────────────────────┤
# │ Gymnotus carapo           │ Gymnotidae    │ Salmonidae (0.718)    │ Epinephelidae (0.153) │ Gymnotidae (0.127) │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼────────────────────┤
# │ Electrophorus electricus  │ Gymnotidae    │ Gymnotidae (0.956)    │ Sphyraenidae (0.024)  │ Moronidae (0.011)  │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼────────────────────┤
# │ Morone americana          │ Moronidae     │ Moronidae (0.963)     │ Epinephelidae (0.017) │ Salmonidae (0.011) │
# ╘═══════════════════════════╧═══════════════╧═══════════════════════╧═══════════════════════╧════════════════════╛
#
# --------------- Epoch 14 ---------------
# Epoch 14 | Step 10/79 | Running average step loss: 1.1332
# Epoch 14 | Step 20/79 | Running average step loss: 1.0562
# Epoch 14 | Step 30/79 | Running average step loss: 1.0323
# Epoch 14 | Step 40/79 | Running average step loss: 1.0487
# Epoch 14 | Step 50/79 | Running average step loss: 1.0597
# Epoch 14 | Step 60/79 | Running average step loss: 1.0685
# Epoch 14 | Step 70/79 | Running average step loss: 1.0649
# Epoch 14 | Epoch average loss: 1.0689
#
# ╒═══════════════════════════╤═══════════════╤═══════════════════════╤═══════════════════════╤═══════════════════════╕
# │ Image                     │ True Family   │ Top-1                 │ Top-2                 │ Top-3                 │
# ╞═══════════════════════════╪═══════════════╪═══════════════════════╪═══════════════════════╪═══════════════════════╡
# │ Salmo hucho               │ Salmonidae    │ Salmonidae (1.000)    │ Epinephelidae (0.000) │ Sphyraenidae (0.000)  │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Sphyraena novaehollandiae │ Sphyraenidae  │ Sphyraenidae (0.999)  │ Gymnotidae (0.000)    │ Epinephelidae (0.000) │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Centropyge boylei         │ Pomacanthidae │ Pomacanthidae (0.898) │ Gymnotidae (0.043)    │ Sphyraenidae (0.029)  │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Gymnotus carapo           │ Gymnotidae    │ Salmonidae (0.732)    │ Epinephelidae (0.183) │ Gymnotidae (0.084)    │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Electrophorus electricus  │ Gymnotidae    │ Gymnotidae (0.973)    │ Sphyraenidae (0.023)  │ Epinephelidae (0.002) │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Morone americana          │ Moronidae     │ Moronidae (0.934)     │ Epinephelidae (0.049) │ Pomacanthidae (0.010) │
# ╘═══════════════════════════╧═══════════════╧═══════════════════════╧═══════════════════════╧═══════════════════════╛
#
# --------------- Epoch 15 ---------------
# Epoch 15 | Step 10/79 | Running average step loss: 0.9559
# Epoch 15 | Step 20/79 | Running average step loss: 0.9409
# Epoch 15 | Step 30/79 | Running average step loss: 1.0280
# Epoch 15 | Step 40/79 | Running average step loss: 1.0536
# Epoch 15 | Step 50/79 | Running average step loss: 1.0411
# Epoch 15 | Step 60/79 | Running average step loss: 1.0380
# Epoch 15 | Step 70/79 | Running average step loss: 1.0406
# Epoch 15 | Epoch average loss: 1.0310
#
# ╒═══════════════════════════╤═══════════════╤═══════════════════════╤═══════════════════════╤═══════════════════════╕
# │ Image                     │ True Family   │ Top-1                 │ Top-2                 │ Top-3                 │
# ╞═══════════════════════════╪═══════════════╪═══════════════════════╪═══════════════════════╪═══════════════════════╡
# │ Salmo hucho               │ Salmonidae    │ Salmonidae (0.996)    │ Moronidae (0.001)     │ Sphyraenidae (0.001)  │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Sphyraena novaehollandiae │ Sphyraenidae  │ Sphyraenidae (0.996)  │ Gymnotidae (0.002)    │ Epinephelidae (0.001) │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Centropyge boylei         │ Pomacanthidae │ Pomacanthidae (0.985) │ Gymnotidae (0.005)    │ Salmonidae (0.004)    │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Gymnotus carapo           │ Gymnotidae    │ Epinephelidae (0.564) │ Salmonidae (0.225)    │ Gymnotidae (0.210)    │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Electrophorus electricus  │ Gymnotidae    │ Gymnotidae (0.984)    │ Sphyraenidae (0.008)  │ Epinephelidae (0.005) │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Morone americana          │ Moronidae     │ Moronidae (0.978)     │ Epinephelidae (0.015) │ Salmonidae (0.004)    │
# ╘═══════════════════════════╧═══════════════╧═══════════════════════╧═══════════════════════╧═══════════════════════╛
#
# --------------- Epoch 16 ---------------
# Epoch 16 | Step 10/79 | Running average step loss: 1.1216
# Epoch 16 | Step 20/79 | Running average step loss: 1.0676
# Epoch 16 | Step 30/79 | Running average step loss: 1.0629
# Epoch 16 | Step 40/79 | Running average step loss: 1.0275
# Epoch 16 | Step 50/79 | Running average step loss: 1.0092
# Epoch 16 | Step 60/79 | Running average step loss: 1.0390
# Epoch 16 | Step 70/79 | Running average step loss: 1.0357
# Epoch 16 | Epoch average loss: 1.0397
#
# ╒═══════════════════════════╤═══════════════╤═══════════════════════╤═══════════════════════╤═══════════════════════╕
# │ Image                     │ True Family   │ Top-1                 │ Top-2                 │ Top-3                 │
# ╞═══════════════════════════╪═══════════════╪═══════════════════════╪═══════════════════════╪═══════════════════════╡
# │ Salmo hucho               │ Salmonidae    │ Salmonidae (0.994)    │ Gymnotidae (0.003)    │ Moronidae (0.002)     │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Sphyraena novaehollandiae │ Sphyraenidae  │ Sphyraenidae (0.993)  │ Gymnotidae (0.006)    │ Salmonidae (0.000)    │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Centropyge boylei         │ Pomacanthidae │ Pomacanthidae (0.954) │ Gymnotidae (0.026)    │ Salmonidae (0.014)    │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Gymnotus carapo           │ Gymnotidae    │ Gymnotidae (0.575)    │ Salmonidae (0.270)    │ Epinephelidae (0.154) │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Electrophorus electricus  │ Gymnotidae    │ Gymnotidae (0.983)    │ Sphyraenidae (0.007)  │ Moronidae (0.005)     │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Morone americana          │ Moronidae     │ Moronidae (0.980)     │ Epinephelidae (0.015) │ Salmonidae (0.002)    │
# ╘═══════════════════════════╧═══════════════╧═══════════════════════╧═══════════════════════╧═══════════════════════╛
#
# --------------- Epoch 17 ---------------
# Epoch 17 | Step 10/79 | Running average step loss: 0.9440
# Epoch 17 | Step 20/79 | Running average step loss: 0.9827
# Epoch 17 | Step 30/79 | Running average step loss: 1.0132
# Epoch 17 | Step 40/79 | Running average step loss: 0.9984
# Epoch 17 | Step 50/79 | Running average step loss: 1.0194
# Epoch 17 | Step 60/79 | Running average step loss: 0.9983
# Epoch 17 | Step 70/79 | Running average step loss: 0.9773
# Epoch 17 | Epoch average loss: 0.9649
#
# ╒═══════════════════════════╤═══════════════╤═══════════════════════╤═══════════════════════╤═══════════════════════╕
# │ Image                     │ True Family   │ Top-1                 │ Top-2                 │ Top-3                 │
# ╞═══════════════════════════╪═══════════════╪═══════════════════════╪═══════════════════════╪═══════════════════════╡
# │ Salmo hucho               │ Salmonidae    │ Salmonidae (0.985)    │ Moronidae (0.014)     │ Gymnotidae (0.001)    │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Sphyraena novaehollandiae │ Sphyraenidae  │ Sphyraenidae (0.997)  │ Gymnotidae (0.002)    │ Moronidae (0.000)     │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Centropyge boylei         │ Pomacanthidae │ Pomacanthidae (0.971) │ Gymnotidae (0.022)    │ Moronidae (0.003)     │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Gymnotus carapo           │ Gymnotidae    │ Epinephelidae (0.497) │ Gymnotidae (0.286)    │ Salmonidae (0.200)    │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Electrophorus electricus  │ Gymnotidae    │ Gymnotidae (0.971)    │ Sphyraenidae (0.018)  │ Moronidae (0.006)     │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Morone americana          │ Moronidae     │ Moronidae (0.999)     │ Epinephelidae (0.001) │ Pomacanthidae (0.000) │
# ╘═══════════════════════════╧═══════════════╧═══════════════════════╧═══════════════════════╧═══════════════════════╛
#
# --------------- Epoch 18 ---------------
# Epoch 18 | Step 10/79 | Running average step loss: 0.8349
# Epoch 18 | Step 20/79 | Running average step loss: 0.9491
# Epoch 18 | Step 30/79 | Running average step loss: 1.0018
# Epoch 18 | Step 40/79 | Running average step loss: 0.9908
# Epoch 18 | Step 50/79 | Running average step loss: 0.9970
# Epoch 18 | Step 60/79 | Running average step loss: 0.9692
# Epoch 18 | Step 70/79 | Running average step loss: 0.9721
# Epoch 18 | Epoch average loss: 0.9593
#
# ╒═══════════════════════════╤═══════════════╤═══════════════════════╤═══════════════════════╤═══════════════════════╕
# │ Image                     │ True Family   │ Top-1                 │ Top-2                 │ Top-3                 │
# ╞═══════════════════════════╪═══════════════╪═══════════════════════╪═══════════════════════╪═══════════════════════╡
# │ Salmo hucho               │ Salmonidae    │ Salmonidae (0.994)    │ Moronidae (0.005)     │ Gymnotidae (0.000)    │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Sphyraena novaehollandiae │ Sphyraenidae  │ Sphyraenidae (0.994)  │ Gymnotidae (0.004)    │ Epinephelidae (0.001) │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Centropyge boylei         │ Pomacanthidae │ Pomacanthidae (0.992) │ Gymnotidae (0.005)    │ Salmonidae (0.002)    │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Gymnotus carapo           │ Gymnotidae    │ Gymnotidae (0.659)    │ Epinephelidae (0.268) │ Salmonidae (0.057)    │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Electrophorus electricus  │ Gymnotidae    │ Gymnotidae (0.995)    │ Epinephelidae (0.002) │ Sphyraenidae (0.002)  │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Morone americana          │ Moronidae     │ Moronidae (0.995)     │ Epinephelidae (0.002) │ Gymnotidae (0.001)    │
# ╘═══════════════════════════╧═══════════════╧═══════════════════════╧═══════════════════════╧═══════════════════════╛
#
# --------------- Epoch 19 ---------------
# Epoch 19 | Step 10/79 | Running average step loss: 1.0898
# Epoch 19 | Step 20/79 | Running average step loss: 1.0564
# Epoch 19 | Step 30/79 | Running average step loss: 1.0810
# Epoch 19 | Step 40/79 | Running average step loss: 1.0939
# Epoch 19 | Step 50/79 | Running average step loss: 1.0694
# Epoch 19 | Step 60/79 | Running average step loss: 1.0341
# Epoch 19 | Step 70/79 | Running average step loss: 1.0397
# Epoch 19 | Epoch average loss: 1.0120
#
# ╒═══════════════════════════╤═══════════════╤═══════════════════════╤══════════════════════╤═══════════════════════╕
# │ Image                     │ True Family   │ Top-1                 │ Top-2                │ Top-3                 │
# ╞═══════════════════════════╪═══════════════╪═══════════════════════╪══════════════════════╪═══════════════════════╡
# │ Salmo hucho               │ Salmonidae    │ Salmonidae (0.999)    │ Moronidae (0.000)    │ Gymnotidae (0.000)    │
# ├───────────────────────────┼───────────────┼───────────────────────┼──────────────────────┼───────────────────────┤
# │ Sphyraena novaehollandiae │ Sphyraenidae  │ Sphyraenidae (0.999)  │ Gymnotidae (0.001)   │ Epinephelidae (0.000) │
# ├───────────────────────────┼───────────────┼───────────────────────┼──────────────────────┼───────────────────────┤
# │ Centropyge boylei         │ Pomacanthidae │ Pomacanthidae (0.975) │ Gymnotidae (0.019)   │ Salmonidae (0.002)    │
# ├───────────────────────────┼───────────────┼───────────────────────┼──────────────────────┼───────────────────────┤
# │ Gymnotus carapo           │ Gymnotidae    │ Epinephelidae (0.404) │ Salmonidae (0.339)   │ Gymnotidae (0.253)    │
# ├───────────────────────────┼───────────────┼───────────────────────┼──────────────────────┼───────────────────────┤
# │ Electrophorus electricus  │ Gymnotidae    │ Gymnotidae (0.985)    │ Sphyraenidae (0.008) │ Epinephelidae (0.006) │
# ├───────────────────────────┼───────────────┼───────────────────────┼──────────────────────┼───────────────────────┤
# │ Morone americana          │ Moronidae     │ Moronidae (0.996)     │ Salmonidae (0.001)   │ Epinephelidae (0.001) │
# ╘═══════════════════════════╧═══════════════╧═══════════════════════╧══════════════════════╧═══════════════════════╛
#
# --------------- Epoch 20 ---------------
# Epoch 20 | Step 10/79 | Running average step loss: 0.9652
# Epoch 20 | Step 20/79 | Running average step loss: 1.0350
# Epoch 20 | Step 30/79 | Running average step loss: 1.0720
# Epoch 20 | Step 40/79 | Running average step loss: 1.0539
# Epoch 20 | Step 50/79 | Running average step loss: 1.0336
# Epoch 20 | Step 60/79 | Running average step loss: 1.0285
# Epoch 20 | Step 70/79 | Running average step loss: 1.0331
# Epoch 20 | Epoch average loss: 1.0429
#
# ╒═══════════════════════════╤═══════════════╤═══════════════════════╤══════════════════════╤═══════════════════════╕
# │ Image                     │ True Family   │ Top-1                 │ Top-2                │ Top-3                 │
# ╞═══════════════════════════╪═══════════════╪═══════════════════════╪══════════════════════╪═══════════════════════╡
# │ Salmo hucho               │ Salmonidae    │ Salmonidae (0.998)    │ Moronidae (0.002)    │ Gymnotidae (0.000)    │
# ├───────────────────────────┼───────────────┼───────────────────────┼──────────────────────┼───────────────────────┤
# │ Sphyraena novaehollandiae │ Sphyraenidae  │ Sphyraenidae (0.997)  │ Gymnotidae (0.002)   │ Epinephelidae (0.000) │
# ├───────────────────────────┼───────────────┼───────────────────────┼──────────────────────┼───────────────────────┤
# │ Centropyge boylei         │ Pomacanthidae │ Pomacanthidae (0.761) │ Gymnotidae (0.139)   │ Salmonidae (0.076)    │
# ├───────────────────────────┼───────────────┼───────────────────────┼──────────────────────┼───────────────────────┤
# │ Gymnotus carapo           │ Gymnotidae    │ Epinephelidae (0.654) │ Salmonidae (0.200)   │ Gymnotidae (0.145)    │
# ├───────────────────────────┼───────────────┼───────────────────────┼──────────────────────┼───────────────────────┤
# │ Electrophorus electricus  │ Gymnotidae    │ Gymnotidae (0.994)    │ Sphyraenidae (0.004) │ Epinephelidae (0.001) │
# ├───────────────────────────┼───────────────┼───────────────────────┼──────────────────────┼───────────────────────┤
# │ Morone americana          │ Moronidae     │ Moronidae (0.998)     │ Gymnotidae (0.000)   │ Pomacanthidae (0.000) │
# ╘═══════════════════════════╧═══════════════╧═══════════════════════╧══════════════════════╧═══════════════════════╛
#
# --------------- Epoch 21 ---------------
# Epoch 21 | Step 10/79 | Running average step loss: 0.9489
# Epoch 21 | Step 20/79 | Running average step loss: 0.9452
# Epoch 21 | Step 30/79 | Running average step loss: 0.9795
# Epoch 21 | Step 40/79 | Running average step loss: 0.9774
# Epoch 21 | Step 50/79 | Running average step loss: 0.9724
# Epoch 21 | Step 60/79 | Running average step loss: 0.9908
# Epoch 21 | Step 70/79 | Running average step loss: 0.9842
# Epoch 21 | Epoch average loss: 0.9715
#
# ╒═══════════════════════════╤═══════════════╤═══════════════════════╤═══════════════════════╤═══════════════════════╕
# │ Image                     │ True Family   │ Top-1                 │ Top-2                 │ Top-3                 │
# ╞═══════════════════════════╪═══════════════╪═══════════════════════╪═══════════════════════╪═══════════════════════╡
# │ Salmo hucho               │ Salmonidae    │ Salmonidae (0.998)    │ Gymnotidae (0.001)    │ Moronidae (0.000)     │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Sphyraena novaehollandiae │ Sphyraenidae  │ Sphyraenidae (0.993)  │ Gymnotidae (0.005)    │ Pomacanthidae (0.001) │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Centropyge boylei         │ Pomacanthidae │ Pomacanthidae (0.830) │ Gymnotidae (0.146)    │ Salmonidae (0.014)    │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Gymnotus carapo           │ Gymnotidae    │ Epinephelidae (0.510) │ Gymnotidae (0.349)    │ Salmonidae (0.138)    │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Electrophorus electricus  │ Gymnotidae    │ Gymnotidae (0.999)    │ Epinephelidae (0.000) │ Pomacanthidae (0.000) │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Morone americana          │ Moronidae     │ Moronidae (0.913)     │ Pomacanthidae (0.081) │ Epinephelidae (0.004) │
# ╘═══════════════════════════╧═══════════════╧═══════════════════════╧═══════════════════════╧═══════════════════════╛
#
# --------------- Epoch 22 ---------------
# Epoch 22 | Step 10/79 | Running average step loss: 1.0420
# Epoch 22 | Step 20/79 | Running average step loss: 1.0923
# Epoch 22 | Step 30/79 | Running average step loss: 1.0726
# Epoch 22 | Step 40/79 | Running average step loss: 1.0304
# Epoch 22 | Step 50/79 | Running average step loss: 1.0058
# Epoch 22 | Step 60/79 | Running average step loss: 1.0017
# Epoch 22 | Step 70/79 | Running average step loss: 1.0030
# Epoch 22 | Epoch average loss: 1.0035
#
# ╒═══════════════════════════╤═══════════════╤═══════════════════════╤═══════════════════════╤═══════════════════════╕
# │ Image                     │ True Family   │ Top-1                 │ Top-2                 │ Top-3                 │
# ╞═══════════════════════════╪═══════════════╪═══════════════════════╪═══════════════════════╪═══════════════════════╡
# │ Salmo hucho               │ Salmonidae    │ Salmonidae (0.995)    │ Gymnotidae (0.002)    │ Epinephelidae (0.001) │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Sphyraena novaehollandiae │ Sphyraenidae  │ Sphyraenidae (0.992)  │ Gymnotidae (0.006)    │ Epinephelidae (0.001) │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Centropyge boylei         │ Pomacanthidae │ Pomacanthidae (0.835) │ Gymnotidae (0.156)    │ Salmonidae (0.005)    │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Gymnotus carapo           │ Gymnotidae    │ Gymnotidae (0.713)    │ Salmonidae (0.227)    │ Epinephelidae (0.055) │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Electrophorus electricus  │ Gymnotidae    │ Gymnotidae (0.996)    │ Sphyraenidae (0.001)  │ Salmonidae (0.001)    │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Morone americana          │ Moronidae     │ Moronidae (0.976)     │ Pomacanthidae (0.016) │ Epinephelidae (0.005) │
# ╘═══════════════════════════╧═══════════════╧═══════════════════════╧═══════════════════════╧═══════════════════════╛
#
# --------------- Epoch 23 ---------------
# Epoch 23 | Step 10/79 | Running average step loss: 0.9927
# Epoch 23 | Step 20/79 | Running average step loss: 0.9698
# Epoch 23 | Step 30/79 | Running average step loss: 0.9875
# Epoch 23 | Step 40/79 | Running average step loss: 0.9878
# Epoch 23 | Step 50/79 | Running average step loss: 0.9693
# Epoch 23 | Step 60/79 | Running average step loss: 0.9727
# Epoch 23 | Step 70/79 | Running average step loss: 0.9832
# Epoch 23 | Epoch average loss: 0.9853
#
# ╒═══════════════════════════╤═══════════════╤═══════════════════════╤═══════════════════════╤═══════════════════════╕
# │ Image                     │ True Family   │ Top-1                 │ Top-2                 │ Top-3                 │
# ╞═══════════════════════════╪═══════════════╪═══════════════════════╪═══════════════════════╪═══════════════════════╡
# │ Salmo hucho               │ Salmonidae    │ Salmonidae (0.994)    │ Moronidae (0.002)     │ Epinephelidae (0.002) │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Sphyraena novaehollandiae │ Sphyraenidae  │ Sphyraenidae (0.996)  │ Gymnotidae (0.003)    │ Pomacanthidae (0.000) │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Centropyge boylei         │ Pomacanthidae │ Pomacanthidae (0.981) │ Gymnotidae (0.015)    │ Salmonidae (0.002)    │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Gymnotus carapo           │ Gymnotidae    │ Gymnotidae (0.657)    │ Salmonidae (0.269)    │ Epinephelidae (0.047) │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Electrophorus electricus  │ Gymnotidae    │ Gymnotidae (0.999)    │ Sphyraenidae (0.000)  │ Moronidae (0.000)     │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Morone americana          │ Moronidae     │ Moronidae (0.977)     │ Pomacanthidae (0.014) │ Epinephelidae (0.005) │
# ╘═══════════════════════════╧═══════════════╧═══════════════════════╧═══════════════════════╧═══════════════════════╛
#
# --------------- Epoch 24 ---------------
# Epoch 24 | Step 10/79 | Running average step loss: 0.9485
# Epoch 24 | Step 20/79 | Running average step loss: 0.9674
# Epoch 24 | Step 30/79 | Running average step loss: 1.0081
# Epoch 24 | Step 40/79 | Running average step loss: 1.0239
# Epoch 24 | Step 50/79 | Running average step loss: 1.0141
# Epoch 24 | Step 60/79 | Running average step loss: 0.9987
# Epoch 24 | Step 70/79 | Running average step loss: 0.9872
# Epoch 24 | Epoch average loss: 0.9841
#
# ╒═══════════════════════════╤═══════════════╤═══════════════════════╤═══════════════════════╤═══════════════════════╕
# │ Image                     │ True Family   │ Top-1                 │ Top-2                 │ Top-3                 │
# ╞═══════════════════════════╪═══════════════╪═══════════════════════╪═══════════════════════╪═══════════════════════╡
# │ Salmo hucho               │ Salmonidae    │ Salmonidae (0.963)    │ Gymnotidae (0.017)    │ Epinephelidae (0.013) │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Sphyraena novaehollandiae │ Sphyraenidae  │ Sphyraenidae (0.972)  │ Gymnotidae (0.027)    │ Epinephelidae (0.001) │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Centropyge boylei         │ Pomacanthidae │ Pomacanthidae (0.853) │ Gymnotidae (0.079)    │ Salmonidae (0.040)    │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Gymnotus carapo           │ Gymnotidae    │ Gymnotidae (0.740)    │ Epinephelidae (0.145) │ Salmonidae (0.105)    │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Electrophorus electricus  │ Gymnotidae    │ Gymnotidae (0.999)    │ Sphyraenidae (0.000)  │ Moronidae (0.000)     │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Morone americana          │ Moronidae     │ Moronidae (0.983)     │ Pomacanthidae (0.008) │ Epinephelidae (0.004) │
# ╘═══════════════════════════╧═══════════════╧═══════════════════════╧═══════════════════════╧═══════════════════════╛
#
# --------------- Epoch 25 ---------------
# Epoch 25 | Step 10/79 | Running average step loss: 0.7880
# Epoch 25 | Step 20/79 | Running average step loss: 0.9037
# Epoch 25 | Step 30/79 | Running average step loss: 0.8885
# Epoch 25 | Step 40/79 | Running average step loss: 0.8820
# Epoch 25 | Step 50/79 | Running average step loss: 0.8710
# Epoch 25 | Step 60/79 | Running average step loss: 0.8471
# Epoch 25 | Step 70/79 | Running average step loss: 0.8688
# Epoch 25 | Epoch average loss: 0.8731
#
# ╒═══════════════════════════╤═══════════════╤═══════════════════════╤═══════════════════════╤═══════════════════════╕
# │ Image                     │ True Family   │ Top-1                 │ Top-2                 │ Top-3                 │
# ╞═══════════════════════════╪═══════════════╪═══════════════════════╪═══════════════════════╪═══════════════════════╡
# │ Salmo hucho               │ Salmonidae    │ Salmonidae (0.995)    │ Moronidae (0.002)     │ Sphyraenidae (0.001)  │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Sphyraena novaehollandiae │ Sphyraenidae  │ Sphyraenidae (0.995)  │ Gymnotidae (0.004)    │ Epinephelidae (0.000) │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Centropyge boylei         │ Pomacanthidae │ Pomacanthidae (0.928) │ Gymnotidae (0.035)    │ Sphyraenidae (0.024)  │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Gymnotus carapo           │ Gymnotidae    │ Gymnotidae (0.556)    │ Epinephelidae (0.382) │ Salmonidae (0.060)    │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Electrophorus electricus  │ Gymnotidae    │ Gymnotidae (0.990)    │ Sphyraenidae (0.008)  │ Moronidae (0.001)     │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Morone americana          │ Moronidae     │ Moronidae (0.996)     │ Epinephelidae (0.002) │ Pomacanthidae (0.001) │
# ╘═══════════════════════════╧═══════════════╧═══════════════════════╧═══════════════════════╧═══════════════════════╛

# %%
torch.save({
        'epoch': 25,
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
        'loss': total_loss,
        }, f"Res101_25F.pt")

# %%
prompts = ["Salmonidae", "Sphyraenidae",
           "Pomacanthidae", "Epinephelidae",
           "Morinidae", "Gymnotidae"]
text_tokens = clip.tokenize(prompts).to(device)
run_evaluation("zeroCLIP")
# Out:
# ╒═══════════════════════════╤═══════════════╤═══════════════════════╤═══════════════════════╤═══════════════════════╕
# │ Image                     │ True Family   │ Top-1                 │ Top-2                 │ Top-3                 │
# ╞═══════════════════════════╪═══════════════╪═══════════════════════╪═══════════════════════╪═══════════════════════╡
# │ Salmo hucho               │ Salmonidae    │ Salmonidae (0.988)    │ Morinidae (0.010)     │ Sphyraenidae (0.001)  │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Sphyraena novaehollandiae │ Sphyraenidae  │ Sphyraenidae (0.995)  │ Gymnotidae (0.004)    │ Epinephelidae (0.000) │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Centropyge boylei         │ Pomacanthidae │ Pomacanthidae (0.869) │ Morinidae (0.069)     │ Gymnotidae (0.033)    │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Gymnotus carapo           │ Gymnotidae    │ Gymnotidae (0.549)    │ Epinephelidae (0.377) │ Salmonidae (0.059)    │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Electrophorus electricus  │ Gymnotidae    │ Gymnotidae (0.991)    │ Sphyraenidae (0.008)  │ Morinidae (0.001)     │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Morone americana          │ Moronidae     │ Morinidae (0.996)     │ Epinephelidae (0.002) │ Pomacanthidae (0.001) │
# ╘═══════════════════════════╧═══════════════╧═══════════════════════╧═══════════════════════╧═══════════════════════╛

# %%
prompts = ["Salmonidae", "Sphyraenidae",
           "Pomacanthidae", "Epinephelidae",
           "Morinidae", "Gymnotidae", "Electrophorus"]
text_tokens = clip.tokenize(prompts).to(device)
run_evaluation("zeroCLIP")
# Out:
# ╒═══════════════════════════╤═══════════════╤═══════════════════════╤═══════════════════════╤═══════════════════════╕
# │ Image                     │ True Family   │ Top-1                 │ Top-2                 │ Top-3                 │
# ╞═══════════════════════════╪═══════════════╪═══════════════════════╪═══════════════════════╪═══════════════════════╡
# │ Salmo hucho               │ Salmonidae    │ Salmonidae (0.986)    │ Morinidae (0.010)     │ Electrophorus (0.001) │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Sphyraena novaehollandiae │ Sphyraenidae  │ Sphyraenidae (0.986)  │ Electrophorus (0.009) │ Gymnotidae (0.004)    │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Centropyge boylei         │ Pomacanthidae │ Pomacanthidae (0.818) │ Morinidae (0.065)     │ Electrophorus (0.058) │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Gymnotus carapo           │ Gymnotidae    │ Gymnotidae (0.475)    │ Epinephelidae (0.326) │ Electrophorus (0.135) │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Electrophorus electricus  │ Gymnotidae    │ Electrophorus (0.673) │ Gymnotidae (0.324)    │ Sphyraenidae (0.003)  │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Morone americana          │ Moronidae     │ Morinidae (0.996)     │ Epinephelidae (0.002) │ Pomacanthidae (0.001) │
# ╘═══════════════════════════╧═══════════════╧═══════════════════════╧═══════════════════════╧═══════════════════════╛
