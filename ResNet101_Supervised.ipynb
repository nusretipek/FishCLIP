# %%
import os
import glob
import random
from pathlib import Path
from tabulate import tabulate
from PIL import Image, ImageOps
from collections import Counter

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import models, transforms

device = "cuda:3" if torch.cuda.is_available() else "cpu"

# %%
TAXA = [
    ("Salmo salar", "Atlantic salmon", "Actinopterygii", "Salmoniformes", "Salmonidae", "Salmo"),
    ("Oncorhynchus mykiss", "Rainbow trout", "Actinopterygii", "Salmoniformes", "Salmonidae", "Oncorhynchus"),
    ("Gadus morhua", "Atlantic cod", "Actinopterygii", "Gadiformes", "Gadidae", "Gadus"),
    ("Melanogrammus aeglefinus", "Haddock", "Actinopterygii", "Gadiformes", "Gadidae", "Melanogrammus"),
    ("Scomber scombrus", "Atlantic mackerel", "Actinopterygii", "Scombriformes", "Scombridae", "Scomber"),
    ("Thunnus thynnus", "Atlantic bluefin tuna", "Actinopterygii", "Scombriformes", "Scombridae", "Thunnus"),
    ("Coryphaena hippurus", "Mahi-mahi", "Actinopterygii", "Carangiformes", "Coryphaenidae", "Coryphaena"),
    ("Xiphias gladius", "Swordfish", "Actinopterygii", "Xiphiiformes", "Xiphiidae", "Xiphias"),
    ("Clupea harengus", "Atlantic herring", "Actinopterygii", "Clupeiformes", "Clupeidae", "Clupea"),
    ("Sardina pilchardus", "European pilchard", "Actinopterygii", "Clupeiformes", "Clupeidae", "Sardina"),
    ("Engraulis encrasicolus", "European anchovy", "Actinopterygii", "Clupeiformes", "Engraulidae", "Engraulis"),
    ("Amphiprion ocellaris", "Ocellaris clownfish", "Actinopterygii", "Blenniiformes", "Pomacentridae", "Amphiprion"),
    ("Pomacanthus imperator", "Emperor angelfish", "Actinopterygii", "Acanthuriformes", "Pomacanthidae", "Pomacanthus"),
    ("Pterois volitans", "Red lionfish", "Actinopterygii", "Scorpaeniformes", "Scorpaenidae", "Pterois"),
    ("Zebrasoma flavescens", "Yellow tang", "Actinopterygii", "Acanthuriformes", "Acanthuridae", "Zebrasoma"),
    ("Hippocampus kuda", "Common seahorse", "Actinopterygii", "Syngnathiformes", "Syngnathidae", "Hippocampus"),
    ("Betta splendens", "Siamese fighting fish", "Actinopterygii", "Anabantiformes", "Osphronemidae", "Betta"),
    ("Paracheirodon innesi", "Neon tetra", "Actinopterygii", "Characiformes", "Characidae", "Paracheirodon"),
    ("Carassius auratus", "Goldfish", "Actinopterygii", "Cypriniformes", "Cyprinidae", "Carassius"),
    ("Cyprinus carpio", "Common carp", "Actinopterygii", "Cypriniformes", "Cyprinidae", "Cyprinus"),
    ("Poecilia reticulata", "Guppy", "Actinopterygii", "Cyprinodontiformes", "Poeciliidae", "Poecilia"),
    ("Astatotilapia burtoni", "Burton’s mouthbrooder", "Actinopterygii", "Cichliformes", "Cichlidae", "Astatotilapia"),
    ("Oreochromis niloticus", "Nile tilapia", "Actinopterygii", "Cichliformes", "Cichlidae", "Oreochromis"),
    ("Pterophyllum scalare", "Freshwater angelfish", "Actinopterygii", "Cichliformes", "Cichlidae", "Pterophyllum"),
    ("Micropterus salmoides", "Florida bass", "Actinopterygii", "Centrarchiformes", "Centrarchidae", "Micropterus"),
    ("Lepomis macrochirus", "Bluegill sunfish", "Actinopterygii", "Centrarchiformes", "Centrarchidae", "Lepomis"),
    ("Esox lucius", "Northern pike", "Actinopterygii", "Esociformes", "Esocidae", "Esox"),
    ("Ictalurus punctatus", "Channel catfish", "Actinopterygii", "Siluriformes", "Ictaluridae", "Ictalurus"),
    ("Silurus glanis", "Wels catfish", "Actinopterygii", "Siluriformes", "Siluridae", "Silurus"),
    ("Electrophorus electricus", "Electric eel", "Actinopterygii", "Gymnotiformes", "Gymnotidae", "Electrophorus"),
    ("Arapaima gigas", "Arapaima", "Actinopterygii", "Osteoglossiformes", "Arapaimidae", "Arapaima"),
    ("Osteoglossum bicirrhosum", "Silver arowana", "Actinopterygii", "Osteoglossiformes", "Osteoglossidae", "Osteoglossum"),
    ("Anguilla anguilla", "European eel", "Actinopterygii", "Anguilliformes", "Anguillidae", "Anguilla"),
    ("Muraena helena", "Mediterranean moray", "Actinopterygii", "Anguilliformes", "Muraenidae", "Muraena"),
    ("Lophius piscatorius", "Monkfish", "Actinopterygii", "Lophiiformes", "Lophiidae", "Lophius"),
    ("Hippoglossus hippoglossus", "Atlantic halibut", "Actinopterygii", "Pleuronectiformes", "Pleuronectidae", "Hippoglossus"),
    ("Pleuronectes platessa", "European plaice", "Actinopterygii", "Pleuronectiformes", "Pleuronectidae", "Pleuronectes"),
    ("Sphyraena barracuda", "Great barracuda", "Actinopterygii", "Carangiformes", "Sphyraenidae", "Sphyraena"),
    ("Dicentrarchus labrax", "European seabass", "Actinopterygii", "Acanthuriformes", "Moronidae", "Dicentrarchus"),
    ("Lutjanus campechanus", "Northern red snapper", "Actinopterygii", "Acanthuriformes", "Lutjanidae", "Lutjanus"),
    ("Epinephelus itajara", "Goliath grouper", "Actinopterygii", "Perciformes", "Epinephelidae", "Epinephelus"),
    ("Cheilinus undulatus", "Humphead wrasse", "Actinopterygii", "Labriformes", "Labridae", "Cheilinus"),
    ("Gobius niger", "Black goby", "Actinopterygii", "Gobiiformes", "Gobiidae", "Gobius"),
    ("Carcharodon carcharias", "Great white shark", "Chondrichthyes", "Lamniformes", "Lamnidae", "Carcharodon"),
    ("Galeocerdo cuvier", "Tiger shark", "Chondrichthyes", "Carcharhiniformes", "Carcharhinidae", "Galeocerdo"),
    ("Sphyrna lewini", "Scalloped hammerhead", "Chondrichthyes", "Carcharhiniformes", "Sphyrnidae", "Sphyrna"),
    ("Raja clavata", "Thornback ray", "Chondrichthyes", "Rajiformes", "Rajidae", "Raja"),
    ("Mobula birostris", "Giant manta ray", "Chondrichthyes", "Myliobatiformes", "Mobulidae", "Mobula"),
    ("Takifugu rubripes", "Japanese pufferfish", "Actinopterygii", "Tetraodontiformes", "Tetraodontidae", "Takifugu"),
    ("Diodon hystrix", "Porcupinefish", "Actinopterygii", "Tetraodontiformes", "Diodontidae", "Diodon"),]


# Extract unique families and create label mapping
families = sorted(list(set([species[4] for species in TAXA])))
family_to_idx = {family: idx for idx, family in enumerate(families)}
idx_to_family = {idx: family for family, idx in family_to_idx.items()}
num_classes = len(families)

print(f"Number of unique families: {num_classes}")
print(f"Families: {families}\n")
# Out:
# Number of unique families: 41
# Families: ['Acanthuridae', 'Anguillidae', 'Arapaimidae', 'Carcharhinidae', 'Centrarchidae', 'Characidae', 'Cichlidae', 'Clupeidae', 'Coryphaenidae', 'Cyprinidae', 'Diodontidae', 'Engraulidae', 'Epinephelidae', 'Esocidae', 'Gadidae', 'Gobiidae', 'Gymnotidae', 'Ictaluridae', 'Labridae', 'Lamnidae', 'Lophiidae', 'Lutjanidae', 'Mobulidae', 'Moronidae', 'Muraenidae', 'Osphronemidae', 'Osteoglossidae', 'Pleuronectidae', 'Poeciliidae', 'Pomacanthidae', 'Pomacentridae', 'Rajidae', 'Salmonidae', 'Scombridae', 'Scorpaenidae', 'Siluridae', 'Sphyraenidae', 'Sphyrnidae', 'Syngnathidae', 'Tetraodontidae', 'Xiphiidae']

# %%
# Define transforms
train_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

eval_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

def build_dataset_lists(root="dataCLIP"):
    root = Path(root)
    image_paths, labels = [], []
    
    for species in TAXA:
        binom, common, cls, order, family, genus = species
        family_idx = family_to_idx[family]
        folder_path = root / binom.replace(" ", "_")
        
        if not folder_path.exists():
            continue
            
        for img in sorted(folder_path.glob("*")):
            if img.suffix.lower() in {".jpg", ".jpeg", ".png", ".webp"}:
                image_paths.append(str(img))
                labels.append(family_idx)
    
    assert len(image_paths) == len(labels)
    return image_paths, labels

class FishDataset(Dataset):
    def __init__(self, image_paths, labels, transform=None):
        self.image_paths = image_paths
        self.labels = labels
        self.transform = transform

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        img_path = self.image_paths[idx]
        label = self.labels[idx]

        img = Image.open(img_path)
        img = ImageOps.exif_transpose(img)
        
        if img.mode == "P" and ("transparency" in img.info or img.info.get("transparency") is not None):
            img = img.convert("RGBA").convert("RGB")
        else:
            img = img.convert("RGB")
        img.load()

        if self.transform:
            img = self.transform(img)

        return img, label

# Build dataset
image_data, label_data = build_dataset_lists("dataCLIP")
dataset = FishDataset(image_data, label_data, transform=train_transform)
train_dataloader = DataLoader(dataset, batch_size=16, shuffle=True)

# %%
# Model setup
model = models.resnet101(weights='IMAGENET1K_V1')
num_features = model.fc.in_features
model.fc = nn.Sequential(
    nn.Linear(num_features, 1024),
    nn.ReLU(inplace=True),
    nn.Dropout(0.3),
    nn.Linear(1024, num_classes)
)
model = model.to(device)

@torch.no_grad()
def predict_image(image_path, model, transform, device, topk=5):
    model.eval()
    
    img = Image.open(image_path)
    img = ImageOps.exif_transpose(img)
    
    if img.mode == "P" and ("transparency" in img.info or img.info.get("transparency") is not None):
        img = img.convert("RGBA").convert("RGB")
    else:
        img = img.convert("RGB")
    img.load()
    
    image = transform(img).unsqueeze(0).to(device)
    outputs = model(image)
    
    probs = torch.softmax(outputs, dim=1).squeeze(0)
    
    k = min(topk, num_classes)
    scores, indices = torch.topk(probs, k=k, largest=True, sorted=True)
    
    return [(float(scores[i]), idx_to_family[int(indices[i])]) for i in range(k)]

def run_evaluation(imgFolder):
    if not os.path.exists(imgFolder):
        print(f"{imgFolder} does not exist.")
        return 
    
    img_files = sorted(glob.glob(f"{imgFolder}/*"))  # Sort for consistent ordering
    if not len(img_files):
        print(f"{imgFolder} is empty.")
        return 

    rows = []
    eval_results = []  # Store results for accurate counting
    
    for name in img_files:
        results = predict_image(name, model, eval_transform, device, topk=3)
        name_split = os.path.basename(name).split(".")[0].split("_")
        
        # Extract true family from filename (format: Genus_species_Family)
        if len(name_split) >= 3:
            true_family = name_split[2]
        else:
            true_family = "Unknown"
        
        # Get predicted families
        pred_families = [label for _, label in results]
        
        # Build table row
        row = [f"{name_split[0]} {name_split[1] if len(name_split) > 1 else ''}"] + [true_family]
        row += [f"{label} ({score:.3f})" for score, label in results]
        rows.append(row)
        
        # Store for accuracy calculation (only if true family is in our training set)
        if true_family in family_to_idx:
            is_top1_correct = (pred_families[0] == true_family)
            is_top3_correct = (true_family in pred_families)
            eval_results.append({
                'name': os.path.basename(name),
                'true_family': true_family,
                'pred_top1': pred_families[0],
                'pred_top3': pred_families,
                'top1_correct': is_top1_correct,
                'top3_correct': is_top3_correct
            })

    # Print table
    headers = ["Image", "True Family", "Top-1", "Top-2", "Top-3"]
    print(tabulate(rows, headers=headers, tablefmt="fancy_grid"))
    
    # Calculate and print accuracy
    if len(eval_results) > 0:
        correct_top1 = sum(r['top1_correct'] for r in eval_results)
        correct_top3 = sum(r['top3_correct'] for r in eval_results)
        total = len(eval_results)
        
        print(f"\nTop-1 Accuracy: {correct_top1}/{total} = {100*correct_top1/total:.2f}%")
        print(f"Top-3 Accuracy: {correct_top3}/{total} = {100*correct_top3/total:.2f}%")
    else:
        print("\nNo valid images found with families in the training set.\n")

# Initial evaluation (before training)
print("=" * 30)
print("INITIAL EVALUATION (Before Training)")
print("=" * 30)
run_evaluation("zeroCLIP")
# Out:
# ==============================
# INITIAL EVALUATION (Before Training)
# ==============================
# ╒═══════════════════════════╤═══════════════╤═════════════════════╤════════════════════╤═══════════════════════╕
# │ Image                     │ True Family   │ Top-1               │ Top-2              │ Top-3                 │
# ╞═══════════════════════════╪═══════════════╪═════════════════════╪════════════════════╪═══════════════════════╡
# │ Centropyge boylei         │ Pomacanthidae │ Poeciliidae (0.030) │ Sphyrnidae (0.030) │ Coryphaenidae (0.030) │
# ├───────────────────────────┼───────────────┼─────────────────────┼────────────────────┼───────────────────────┤
# │ Electrophorus electricus  │ Gymnotidae    │ Xiphiidae (0.031)   │ Siluridae (0.030)  │ Lophiidae (0.030)     │
# ├───────────────────────────┼───────────────┼─────────────────────┼────────────────────┼───────────────────────┤
# │ Gymnotus carapo           │ Gymnotidae    │ Gymnotidae (0.031)  │ Muraenidae (0.030) │ Scombridae (0.030)    │
# ├───────────────────────────┼───────────────┼─────────────────────┼────────────────────┼───────────────────────┤
# │ Morone americana          │ Moronidae     │ Esocidae (0.031)    │ Lamnidae (0.031)   │ Coryphaenidae (0.030) │
# ├───────────────────────────┼───────────────┼─────────────────────┼────────────────────┼───────────────────────┤
# │ Salmo hucho               │ Salmonidae    │ Esocidae (0.030)    │ Scombridae (0.029) │ Gobiidae (0.028)      │
# ├───────────────────────────┼───────────────┼─────────────────────┼────────────────────┼───────────────────────┤
# │ Sphyraena novaehollandiae │ Sphyraenidae  │ Xiphiidae (0.029)   │ Scombridae (0.029) │ Coryphaenidae (0.029) │
# ╘═══════════════════════════╧═══════════════╧═════════════════════╧════════════════════╧═══════════════════════╛
#
# Top-1 Accuracy: 1/6 = 16.67%
# Top-3 Accuracy: 1/6 = 16.67%

# %%
# Training setup
EPOCH = 25
criterion = nn.CrossEntropyLoss(label_smoothing=0.1)
optimizer = optim.AdamW(model.parameters(), lr=1e-4, weight_decay=0.01)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=EPOCH)

# Training loop
for epoch in range(EPOCH):
    model.train()
    epoch_loss_sum = 0.0
    epoch_correct = 0
    epoch_total = 0
    step_idx = 0
    
    print("=" * 50)
    print(f"Epoch {epoch+1}/{EPOCH}")
    print("=" * 50)
    
    for batch in train_dataloader:
        optimizer.zero_grad()

        images, labels = batch
        images = images.to(device)
        labels = labels.to(device)

        outputs = model(images)
        loss = criterion(outputs, labels)

        loss.backward()
        optimizer.step()

        # Calculate batch accuracy
        _, predicted = torch.max(outputs, 1)
        batch_correct = (predicted == labels).sum().item()
        batch_total = labels.size(0)
        
        epoch_loss_sum += loss.item() * batch_total
        epoch_correct += batch_correct
        epoch_total += batch_total
        
        step_idx += 1
        if step_idx % 10 == 0:
            running_loss = epoch_loss_sum / epoch_total
            running_acc = 100 * epoch_correct / epoch_total
            print(f"Step {step_idx}/{len(train_dataloader)} | Loss: {running_loss:.4f} | Acc: {running_acc:.2f}%")
    
    scheduler.step()
    epoch_avg_loss = epoch_loss_sum / epoch_total
    epoch_acc = 100 * epoch_correct / epoch_total
    print(f"\nEpoch {epoch+1} Summary:")
    print(f"  Average Loss: {epoch_avg_loss:.4f}")
    print(f"  Training Accuracy: {epoch_acc:.2f}%\n")
    
    # Run evaluation after each epoch
    print("-" * 30)
    print(f"EVALUATION AFTER EPOCH {epoch+1}")
    print("-" * 30)
    run_evaluation("zeroCLIP")

print("=" * 30)
print("TRAINING COMPLETE")
print("=" * 30)

# Save the trained model
#torch.save(model.state_dict(), 'resnet50_fish_family_classifier.pth')
#print("Model saved to: resnet50_fish_family_classifier.pth")
# Out:
# ==================================================
# Epoch 1/25
# ==================================================
# Step 10/79 | Loss: 3.6704 | Acc: 4.38%
# Step 20/79 | Loss: 3.6011 | Acc: 8.75%
# Step 30/79 | Loss: 3.5213 | Acc: 10.83%
# Step 40/79 | Loss: 3.4668 | Acc: 11.72%
# Step 50/79 | Loss: 3.3521 | Acc: 17.50%
# Step 60/79 | Loss: 3.2477 | Acc: 21.04%
# Step 70/79 | Loss: 3.1535 | Acc: 24.38%
#
# Epoch 1 Summary:
#   Average Loss: 3.0772
#   Training Accuracy: 26.32%
#
# ------------------------------
# EVALUATION AFTER EPOCH 1
# ------------------------------
# ╒═══════════════════════════╤═══════════════╤═══════════════════════╤═══════════════════════╤════════════════════════╕
# │ Image                     │ True Family   │ Top-1                 │ Top-2                 │ Top-3                  │
# ╞═══════════════════════════╪═══════════════╪═══════════════════════╪═══════════════════════╪════════════════════════╡
# │ Centropyge boylei         │ Pomacanthidae │ Pomacentridae (0.137) │ Cichlidae (0.134)     │ Acanthuridae (0.124)   │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼────────────────────────┤
# │ Electrophorus electricus  │ Gymnotidae    │ Gymnotidae (0.462)    │ Anguillidae (0.141)   │ Syngnathidae (0.063)   │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼────────────────────────┤
# │ Gymnotus carapo           │ Gymnotidae    │ Syngnathidae (0.140)  │ Gobiidae (0.127)      │ Pleuronectidae (0.084) │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼────────────────────────┤
# │ Morone americana          │ Moronidae     │ Cichlidae (0.273)     │ Centrarchidae (0.152) │ Salmonidae (0.092)     │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼────────────────────────┤
# │ Salmo hucho               │ Salmonidae    │ Salmonidae (0.634)    │ Clupeidae (0.040)     │ Gadidae (0.029)        │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼────────────────────────┤
# │ Sphyraena novaehollandiae │ Sphyraenidae  │ Clupeidae (0.133)     │ Characidae (0.123)    │ Engraulidae (0.069)    │
# ╘═══════════════════════════╧═══════════════╧═══════════════════════╧═══════════════════════╧════════════════════════╛
#
# Top-1 Accuracy: 2/6 = 33.33%
# Top-3 Accuracy: 2/6 = 33.33%
# ==================================================
# Epoch 2/25
# ==================================================
# Step 10/79 | Loss: 1.9136 | Acc: 62.50%
# Step 20/79 | Loss: 1.9292 | Acc: 63.75%
# Step 30/79 | Loss: 1.9034 | Acc: 64.17%
# Step 40/79 | Loss: 1.8352 | Acc: 66.72%
# Step 50/79 | Loss: 1.7868 | Acc: 67.88%
# Step 60/79 | Loss: 1.7505 | Acc: 68.85%
# Step 70/79 | Loss: 1.7075 | Acc: 69.91%
#
# Epoch 2 Summary:
#   Average Loss: 1.6892
#   Training Accuracy: 70.56%
#
# ------------------------------
# EVALUATION AFTER EPOCH 2
# ------------------------------
# ╒═══════════════════════════╤═══════════════╤═══════════════════════╤═════════════════════╤═════════════════════╕
# │ Image                     │ True Family   │ Top-1                 │ Top-2               │ Top-3               │
# ╞═══════════════════════════╪═══════════════╪═══════════════════════╪═════════════════════╪═════════════════════╡
# │ Centropyge boylei         │ Pomacanthidae │ Pomacanthidae (0.292) │ Cichlidae (0.159)   │ Poeciliidae (0.106) │
# ├───────────────────────────┼───────────────┼───────────────────────┼─────────────────────┼─────────────────────┤
# │ Electrophorus electricus  │ Gymnotidae    │ Gymnotidae (0.577)    │ Anguillidae (0.341) │ Siluridae (0.013)   │
# ├───────────────────────────┼───────────────┼───────────────────────┼─────────────────────┼─────────────────────┤
# │ Gymnotus carapo           │ Gymnotidae    │ Muraenidae (0.670)    │ Gymnotidae (0.071)  │ Anguillidae (0.069) │
# ├───────────────────────────┼───────────────┼───────────────────────┼─────────────────────┼─────────────────────┤
# │ Morone americana          │ Moronidae     │ Cichlidae (0.531)     │ Clupeidae (0.157)   │ Poeciliidae (0.086) │
# ├───────────────────────────┼───────────────┼───────────────────────┼─────────────────────┼─────────────────────┤
# │ Salmo hucho               │ Salmonidae    │ Salmonidae (0.628)    │ Ictaluridae (0.123) │ Esocidae (0.058)    │
# ├───────────────────────────┼───────────────┼───────────────────────┼─────────────────────┼─────────────────────┤
# │ Sphyraena novaehollandiae │ Sphyraenidae  │ Clupeidae (0.638)     │ Engraulidae (0.157) │ Scombridae (0.026)  │
# ╘═══════════════════════════╧═══════════════╧═══════════════════════╧═════════════════════╧═════════════════════╛
#
# Top-1 Accuracy: 3/6 = 50.00%
# Top-3 Accuracy: 4/6 = 66.67%
# ==================================================
# Epoch 3/25
# ==================================================
# Step 10/79 | Loss: 1.2847 | Acc: 79.38%
# Step 20/79 | Loss: 1.2921 | Acc: 79.38%
# Step 30/79 | Loss: 1.2866 | Acc: 80.00%
# Step 40/79 | Loss: 1.2292 | Acc: 83.12%
# Step 50/79 | Loss: 1.2051 | Acc: 84.38%
# Step 60/79 | Loss: 1.1867 | Acc: 85.31%
# Step 70/79 | Loss: 1.1748 | Acc: 86.16%
#
# Epoch 3 Summary:
#   Average Loss: 1.1728
#   Training Accuracy: 86.72%
#
# ------------------------------
# EVALUATION AFTER EPOCH 3
# ------------------------------
# ╒═══════════════════════════╤═══════════════╤═══════════════════════╤═══════════════════════╤════════════════════════╕
# │ Image                     │ True Family   │ Top-1                 │ Top-2                 │ Top-3                  │
# ╞═══════════════════════════╪═══════════════╪═══════════════════════╪═══════════════════════╪════════════════════════╡
# │ Centropyge boylei         │ Pomacanthidae │ Pomacentridae (0.325) │ Pomacanthidae (0.196) │ Cichlidae (0.059)      │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼────────────────────────┤
# │ Electrophorus electricus  │ Gymnotidae    │ Anguillidae (0.746)   │ Gymnotidae (0.240)    │ Siluridae (0.007)      │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼────────────────────────┤
# │ Gymnotus carapo           │ Gymnotidae    │ Gobiidae (0.799)      │ Anguillidae (0.056)   │ Muraenidae (0.032)     │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼────────────────────────┤
# │ Morone americana          │ Moronidae     │ Centrarchidae (0.568) │ Moronidae (0.275)     │ Clupeidae (0.027)      │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼────────────────────────┤
# │ Salmo hucho               │ Salmonidae    │ Ictaluridae (0.272)   │ Gadidae (0.177)       │ Carcharhinidae (0.141) │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼────────────────────────┤
# │ Sphyraena novaehollandiae │ Sphyraenidae  │ Scombridae (0.247)    │ Engraulidae (0.239)   │ Clupeidae (0.178)      │
# ╘═══════════════════════════╧═══════════════╧═══════════════════════╧═══════════════════════╧════════════════════════╛
#
# Top-1 Accuracy: 0/6 = 0.00%
# Top-3 Accuracy: 3/6 = 50.00%
# ==================================================
# Epoch 4/25
# ==================================================
# Step 10/79 | Loss: 0.9953 | Acc: 93.12%
# Step 20/79 | Loss: 0.9760 | Acc: 94.38%
# Step 30/79 | Loss: 0.9696 | Acc: 94.58%
# Step 40/79 | Loss: 0.9709 | Acc: 94.53%
# Step 50/79 | Loss: 0.9610 | Acc: 94.75%
# Step 60/79 | Loss: 0.9541 | Acc: 94.79%
# Step 70/79 | Loss: 0.9514 | Acc: 94.73%
#
# Epoch 4 Summary:
#   Average Loss: 0.9638
#   Training Accuracy: 94.40%
#
# ------------------------------
# EVALUATION AFTER EPOCH 4
# ------------------------------
# ╒═══════════════════════════╤═══════════════╤═══════════════════════╤═══════════════════════╤═════════════════════╕
# │ Image                     │ True Family   │ Top-1                 │ Top-2                 │ Top-3               │
# ╞═══════════════════════════╪═══════════════╪═══════════════════════╪═══════════════════════╪═════════════════════╡
# │ Centropyge boylei         │ Pomacanthidae │ Pomacanthidae (0.477) │ Pomacentridae (0.079) │ Cichlidae (0.065)   │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼─────────────────────┤
# │ Electrophorus electricus  │ Gymnotidae    │ Gymnotidae (0.992)    │ Anguillidae (0.006)   │ Siluridae (0.000)   │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼─────────────────────┤
# │ Gymnotus carapo           │ Gymnotidae    │ Anguillidae (0.209)   │ Gobiidae (0.170)      │ Salmonidae (0.122)  │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼─────────────────────┤
# │ Morone americana          │ Moronidae     │ Moronidae (0.411)     │ Clupeidae (0.271)     │ Cichlidae (0.087)   │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼─────────────────────┤
# │ Salmo hucho               │ Salmonidae    │ Salmonidae (0.803)    │ Clupeidae (0.031)     │ Ictaluridae (0.027) │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼─────────────────────┤
# │ Sphyraena novaehollandiae │ Sphyraenidae  │ Clupeidae (0.559)     │ Engraulidae (0.194)   │ Characidae (0.065)  │
# ╘═══════════════════════════╧═══════════════╧═══════════════════════╧═══════════════════════╧═════════════════════╛
#
# Top-1 Accuracy: 4/6 = 66.67%
# Top-3 Accuracy: 4/6 = 66.67%
# ==================================================
# Epoch 5/25
# ==================================================
# Step 10/79 | Loss: 0.9299 | Acc: 95.00%
# Step 20/79 | Loss: 0.9277 | Acc: 95.00%
# Step 30/79 | Loss: 0.9123 | Acc: 95.83%
# Step 40/79 | Loss: 0.9409 | Acc: 95.00%
# Step 50/79 | Loss: 0.9358 | Acc: 95.00%
# Step 60/79 | Loss: 0.9226 | Acc: 95.52%
# Step 70/79 | Loss: 0.9210 | Acc: 95.62%
#
# Epoch 5 Summary:
#   Average Loss: 0.9174
#   Training Accuracy: 95.76%
#
# ------------------------------
# EVALUATION AFTER EPOCH 5
# ------------------------------
# ╒═══════════════════════════╤═══════════════╤═══════════════════════╤═════════════════════╤════════════════════════╕
# │ Image                     │ True Family   │ Top-1                 │ Top-2               │ Top-3                  │
# ╞═══════════════════════════╪═══════════════╪═══════════════════════╪═════════════════════╪════════════════════════╡
# │ Centropyge boylei         │ Pomacanthidae │ Pomacanthidae (0.348) │ Cichlidae (0.132)   │ Acanthuridae (0.055)   │
# ├───────────────────────────┼───────────────┼───────────────────────┼─────────────────────┼────────────────────────┤
# │ Electrophorus electricus  │ Gymnotidae    │ Gymnotidae (0.982)    │ Anguillidae (0.010) │ Arapaimidae (0.002)    │
# ├───────────────────────────┼───────────────┼───────────────────────┼─────────────────────┼────────────────────────┤
# │ Gymnotus carapo           │ Gymnotidae    │ Gobiidae (0.388)      │ Muraenidae (0.123)  │ Anguillidae (0.101)    │
# ├───────────────────────────┼───────────────┼───────────────────────┼─────────────────────┼────────────────────────┤
# │ Morone americana          │ Moronidae     │ Cichlidae (0.375)     │ Moronidae (0.151)   │ Clupeidae (0.077)      │
# ├───────────────────────────┼───────────────┼───────────────────────┼─────────────────────┼────────────────────────┤
# │ Salmo hucho               │ Salmonidae    │ Salmonidae (0.192)    │ Clupeidae (0.117)   │ Carcharhinidae (0.109) │
# ├───────────────────────────┼───────────────┼───────────────────────┼─────────────────────┼────────────────────────┤
# │ Sphyraena novaehollandiae │ Sphyraenidae  │ Clupeidae (0.363)     │ Engraulidae (0.308) │ Characidae (0.071)     │
# ╘═══════════════════════════╧═══════════════╧═══════════════════════╧═════════════════════╧════════════════════════╛
#
# Top-1 Accuracy: 3/6 = 50.00%
# Top-3 Accuracy: 4/6 = 66.67%
# ==================================================
# Epoch 6/25
# ==================================================
# Step 10/79 | Loss: 0.9191 | Acc: 93.75%
# Step 20/79 | Loss: 0.9071 | Acc: 95.31%
# Step 30/79 | Loss: 0.8900 | Acc: 96.04%
# Step 40/79 | Loss: 0.8840 | Acc: 96.25%
# Step 50/79 | Loss: 0.8836 | Acc: 96.38%
# Step 60/79 | Loss: 0.8750 | Acc: 96.77%
# Step 70/79 | Loss: 0.8751 | Acc: 96.70%
#
# Epoch 6 Summary:
#   Average Loss: 0.8782
#   Training Accuracy: 96.48%
#
# ------------------------------
# EVALUATION AFTER EPOCH 6
# ------------------------------
# ╒═══════════════════════════╤═══════════════╤═══════════════════════╤═════════════════════╤═══════════════════════╕
# │ Image                     │ True Family   │ Top-1                 │ Top-2               │ Top-3                 │
# ╞═══════════════════════════╪═══════════════╪═══════════════════════╪═════════════════════╪═══════════════════════╡
# │ Centropyge boylei         │ Pomacanthidae │ Pomacanthidae (0.344) │ Cichlidae (0.251)   │ Pomacentridae (0.052) │
# ├───────────────────────────┼───────────────┼───────────────────────┼─────────────────────┼───────────────────────┤
# │ Electrophorus electricus  │ Gymnotidae    │ Gymnotidae (0.986)    │ Anguillidae (0.003) │ Arapaimidae (0.002)   │
# ├───────────────────────────┼───────────────┼───────────────────────┼─────────────────────┼───────────────────────┤
# │ Gymnotus carapo           │ Gymnotidae    │ Muraenidae (0.186)    │ Gobiidae (0.184)    │ Salmonidae (0.149)    │
# ├───────────────────────────┼───────────────┼───────────────────────┼─────────────────────┼───────────────────────┤
# │ Morone americana          │ Moronidae     │ Cichlidae (0.379)     │ Moronidae (0.256)   │ Centrarchidae (0.083) │
# ├───────────────────────────┼───────────────┼───────────────────────┼─────────────────────┼───────────────────────┤
# │ Salmo hucho               │ Salmonidae    │ Salmonidae (0.196)    │ Gadidae (0.179)     │ Ictaluridae (0.128)   │
# ├───────────────────────────┼───────────────┼───────────────────────┼─────────────────────┼───────────────────────┤
# │ Sphyraena novaehollandiae │ Sphyraenidae  │ Clupeidae (0.600)     │ Engraulidae (0.272) │ Moronidae (0.020)     │
# ╘═══════════════════════════╧═══════════════╧═══════════════════════╧═════════════════════╧═══════════════════════╛
#
# Top-1 Accuracy: 3/6 = 50.00%
# Top-3 Accuracy: 4/6 = 66.67%
# ==================================================
# Epoch 7/25
# ==================================================
# Step 10/79 | Loss: 0.8593 | Acc: 96.88%
# Step 20/79 | Loss: 0.8340 | Acc: 98.12%
# Step 30/79 | Loss: 0.8281 | Acc: 97.92%
# Step 40/79 | Loss: 0.8305 | Acc: 97.81%
# Step 50/79 | Loss: 0.8251 | Acc: 98.12%
# Step 60/79 | Loss: 0.8196 | Acc: 98.23%
# Step 70/79 | Loss: 0.8190 | Acc: 98.21%
#
# Epoch 7 Summary:
#   Average Loss: 0.8217
#   Training Accuracy: 98.16%
#
# ------------------------------
# EVALUATION AFTER EPOCH 7
# ------------------------------
# ╒═══════════════════════════╤═══════════════╤═══════════════════════╤═══════════════════════╤═════════════════════╕
# │ Image                     │ True Family   │ Top-1                 │ Top-2                 │ Top-3               │
# ╞═══════════════════════════╪═══════════════╪═══════════════════════╪═══════════════════════╪═════════════════════╡
# │ Centropyge boylei         │ Pomacanthidae │ Pomacanthidae (0.433) │ Pomacentridae (0.131) │ Cyprinidae (0.087)  │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼─────────────────────┤
# │ Electrophorus electricus  │ Gymnotidae    │ Gymnotidae (0.972)    │ Anguillidae (0.007)   │ Siluridae (0.002)   │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼─────────────────────┤
# │ Gymnotus carapo           │ Gymnotidae    │ Muraenidae (0.288)    │ Anguillidae (0.179)   │ Salmonidae (0.103)  │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼─────────────────────┤
# │ Morone americana          │ Moronidae     │ Moronidae (0.391)     │ Centrarchidae (0.313) │ Cichlidae (0.058)   │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼─────────────────────┤
# │ Salmo hucho               │ Salmonidae    │ Salmonidae (0.626)    │ Moronidae (0.122)     │ Ictaluridae (0.072) │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼─────────────────────┤
# │ Sphyraena novaehollandiae │ Sphyraenidae  │ Engraulidae (0.357)   │ Sphyraenidae (0.217)  │ Clupeidae (0.078)   │
# ╘═══════════════════════════╧═══════════════╧═══════════════════════╧═══════════════════════╧═════════════════════╛
#
# Top-1 Accuracy: 4/6 = 66.67%
# Top-3 Accuracy: 5/6 = 83.33%
# ==================================================
# Epoch 8/25
# ==================================================
# Step 10/79 | Loss: 0.8239 | Acc: 97.50%
# Step 20/79 | Loss: 0.8255 | Acc: 98.12%
# Step 30/79 | Loss: 0.8200 | Acc: 98.12%
# Step 40/79 | Loss: 0.8122 | Acc: 98.44%
# Step 50/79 | Loss: 0.8078 | Acc: 98.50%
# Step 60/79 | Loss: 0.8128 | Acc: 98.33%
# Step 70/79 | Loss: 0.8130 | Acc: 98.39%
#
# Epoch 8 Summary:
#   Average Loss: 0.8088
#   Training Accuracy: 98.56%
#
# ------------------------------
# EVALUATION AFTER EPOCH 8
# ------------------------------
# ╒═══════════════════════════╤═══════════════╤═══════════════════════╤═══════════════════════╤═══════════════════════╕
# │ Image                     │ True Family   │ Top-1                 │ Top-2                 │ Top-3                 │
# ╞═══════════════════════════╪═══════════════╪═══════════════════════╪═══════════════════════╪═══════════════════════╡
# │ Centropyge boylei         │ Pomacanthidae │ Pomacanthidae (0.243) │ Pomacentridae (0.142) │ Cyprinidae (0.098)    │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Electrophorus electricus  │ Gymnotidae    │ Gymnotidae (0.843)    │ Anguillidae (0.056)   │ Siluridae (0.007)     │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Gymnotus carapo           │ Gymnotidae    │ Muraenidae (0.277)    │ Anguillidae (0.175)   │ Esocidae (0.171)      │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Morone americana          │ Moronidae     │ Salmonidae (0.290)    │ Moronidae (0.200)     │ Centrarchidae (0.167) │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Salmo hucho               │ Salmonidae    │ Salmonidae (0.935)    │ Clupeidae (0.008)     │ Ictaluridae (0.007)   │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Sphyraena novaehollandiae │ Sphyraenidae  │ Sphyraenidae (0.568)  │ Xiphiidae (0.066)     │ Engraulidae (0.056)   │
# ╘═══════════════════════════╧═══════════════╧═══════════════════════╧═══════════════════════╧═══════════════════════╛
#
# Top-1 Accuracy: 4/6 = 66.67%
# Top-3 Accuracy: 5/6 = 83.33%
# ==================================================
# Epoch 9/25
# ==================================================
# Step 10/79 | Loss: 0.7700 | Acc: 100.00%
# Step 20/79 | Loss: 0.7782 | Acc: 99.69%
# Step 30/79 | Loss: 0.7778 | Acc: 99.58%
# Step 40/79 | Loss: 0.7850 | Acc: 99.38%
# Step 50/79 | Loss: 0.7857 | Acc: 99.25%
# Step 60/79 | Loss: 0.7835 | Acc: 99.38%
# Step 70/79 | Loss: 0.7795 | Acc: 99.38%
#
# Epoch 9 Summary:
#   Average Loss: 0.7864
#   Training Accuracy: 99.28%
#
# ------------------------------
# EVALUATION AFTER EPOCH 9
# ------------------------------
# ╒═══════════════════════════╤═══════════════╤═══════════════════════╤═══════════════════════╤═══════════════════════╕
# │ Image                     │ True Family   │ Top-1                 │ Top-2                 │ Top-3                 │
# ╞═══════════════════════════╪═══════════════╪═══════════════════════╪═══════════════════════╪═══════════════════════╡
# │ Centropyge boylei         │ Pomacanthidae │ Cyprinidae (0.418)    │ Pomacanthidae (0.147) │ Pomacentridae (0.112) │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Electrophorus electricus  │ Gymnotidae    │ Gymnotidae (0.973)    │ Anguillidae (0.005)   │ Characidae (0.002)    │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Gymnotus carapo           │ Gymnotidae    │ Muraenidae (0.772)    │ Anguillidae (0.048)   │ Gobiidae (0.037)      │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Morone americana          │ Moronidae     │ Centrarchidae (0.573) │ Moronidae (0.063)     │ Cyprinidae (0.062)    │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Salmo hucho               │ Salmonidae    │ Salmonidae (0.820)    │ Arapaimidae (0.023)   │ Gymnotidae (0.016)    │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Sphyraena novaehollandiae │ Sphyraenidae  │ Sphyraenidae (0.507)  │ Characidae (0.122)    │ Engraulidae (0.049)   │
# ╘═══════════════════════════╧═══════════════╧═══════════════════════╧═══════════════════════╧═══════════════════════╛
#
# Top-1 Accuracy: 3/6 = 50.00%
# Top-3 Accuracy: 5/6 = 83.33%
# ==================================================
# Epoch 10/25
# ==================================================
# Step 10/79 | Loss: 0.7770 | Acc: 99.38%
# Step 20/79 | Loss: 0.7788 | Acc: 99.06%
# Step 30/79 | Loss: 0.7742 | Acc: 99.17%
# Step 40/79 | Loss: 0.7747 | Acc: 99.22%
# Step 50/79 | Loss: 0.7727 | Acc: 99.25%
# Step 60/79 | Loss: 0.7722 | Acc: 99.27%
# Step 70/79 | Loss: 0.7713 | Acc: 99.29%
#
# Epoch 10 Summary:
#   Average Loss: 0.7748
#   Training Accuracy: 99.20%
#
# ------------------------------
# EVALUATION AFTER EPOCH 10
# ------------------------------
# ╒═══════════════════════════╤═══════════════╤═══════════════════════╤═══════════════════════╤═════════════════════╕
# │ Image                     │ True Family   │ Top-1                 │ Top-2                 │ Top-3               │
# ╞═══════════════════════════╪═══════════════╪═══════════════════════╪═══════════════════════╪═════════════════════╡
# │ Centropyge boylei         │ Pomacanthidae │ Pomacanthidae (0.340) │ Pomacentridae (0.213) │ Cyprinidae (0.184)  │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼─────────────────────┤
# │ Electrophorus electricus  │ Gymnotidae    │ Gymnotidae (0.957)    │ Anguillidae (0.007)   │ Siluridae (0.003)   │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼─────────────────────┤
# │ Gymnotus carapo           │ Gymnotidae    │ Muraenidae (0.414)    │ Gobiidae (0.118)      │ Anguillidae (0.091) │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼─────────────────────┤
# │ Morone americana          │ Moronidae     │ Cichlidae (0.475)     │ Centrarchidae (0.365) │ Moronidae (0.033)   │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼─────────────────────┤
# │ Salmo hucho               │ Salmonidae    │ Salmonidae (0.866)    │ Esocidae (0.018)      │ Arapaimidae (0.017) │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼─────────────────────┤
# │ Sphyraena novaehollandiae │ Sphyraenidae  │ Sphyraenidae (0.354)  │ Engraulidae (0.248)   │ Xiphiidae (0.050)   │
# ╘═══════════════════════════╧═══════════════╧═══════════════════════╧═══════════════════════╧═════════════════════╛
#
# Top-1 Accuracy: 4/6 = 66.67%
# Top-3 Accuracy: 5/6 = 83.33%
# ==================================================
# Epoch 11/25
# ==================================================
# Step 10/79 | Loss: 0.7822 | Acc: 98.75%
# Step 20/79 | Loss: 0.7704 | Acc: 99.38%
# Step 30/79 | Loss: 0.7673 | Acc: 99.58%
# Step 40/79 | Loss: 0.7662 | Acc: 99.53%
# Step 50/79 | Loss: 0.7653 | Acc: 99.50%
# Step 60/79 | Loss: 0.7656 | Acc: 99.48%
# Step 70/79 | Loss: 0.7638 | Acc: 99.55%
#
# Epoch 11 Summary:
#   Average Loss: 0.7635
#   Training Accuracy: 99.52%
#
# ------------------------------
# EVALUATION AFTER EPOCH 11
# ------------------------------
# ╒═══════════════════════════╤═══════════════╤═══════════════════════╤═══════════════════════╤═══════════════════════╕
# │ Image                     │ True Family   │ Top-1                 │ Top-2                 │ Top-3                 │
# ╞═══════════════════════════╪═══════════════╪═══════════════════════╪═══════════════════════╪═══════════════════════╡
# │ Centropyge boylei         │ Pomacanthidae │ Pomacanthidae (0.279) │ Cyprinidae (0.239)    │ Pomacentridae (0.148) │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Electrophorus electricus  │ Gymnotidae    │ Gymnotidae (0.885)    │ Anguillidae (0.017)   │ Siluridae (0.010)     │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Gymnotus carapo           │ Gymnotidae    │ Muraenidae (0.394)    │ Esocidae (0.116)      │ Gobiidae (0.078)      │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Morone americana          │ Moronidae     │ Moronidae (0.496)     │ Centrarchidae (0.086) │ Cyprinidae (0.072)    │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Salmo hucho               │ Salmonidae    │ Salmonidae (0.547)    │ Ictaluridae (0.219)   │ Esocidae (0.029)      │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Sphyraena novaehollandiae │ Sphyraenidae  │ Sphyraenidae (0.484)  │ Engraulidae (0.117)   │ Xiphiidae (0.086)     │
# ╘═══════════════════════════╧═══════════════╧═══════════════════════╧═══════════════════════╧═══════════════════════╛
#
# Top-1 Accuracy: 5/6 = 83.33%
# Top-3 Accuracy: 5/6 = 83.33%
# ==================================================
# Epoch 12/25
# ==================================================
# Step 10/79 | Loss: 0.7812 | Acc: 98.75%
# Step 20/79 | Loss: 0.7697 | Acc: 99.38%
# Step 30/79 | Loss: 0.7635 | Acc: 99.38%
# Step 40/79 | Loss: 0.7600 | Acc: 99.53%
# Step 50/79 | Loss: 0.7569 | Acc: 99.62%
# Step 60/79 | Loss: 0.7579 | Acc: 99.58%
# Step 70/79 | Loss: 0.7578 | Acc: 99.55%
#
# Epoch 12 Summary:
#   Average Loss: 0.7593
#   Training Accuracy: 99.60%
#
# ------------------------------
# EVALUATION AFTER EPOCH 12
# ------------------------------
# ╒═══════════════════════════╤═══════════════╤═══════════════════════╤═══════════════════════╤═════════════════════╕
# │ Image                     │ True Family   │ Top-1                 │ Top-2                 │ Top-3               │
# ╞═══════════════════════════╪═══════════════╪═══════════════════════╪═══════════════════════╪═════════════════════╡
# │ Centropyge boylei         │ Pomacanthidae │ Pomacanthidae (0.246) │ Pomacentridae (0.239) │ Cichlidae (0.115)   │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼─────────────────────┤
# │ Electrophorus electricus  │ Gymnotidae    │ Gymnotidae (0.967)    │ Siluridae (0.003)     │ Anguillidae (0.003) │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼─────────────────────┤
# │ Gymnotus carapo           │ Gymnotidae    │ Muraenidae (0.689)    │ Gobiidae (0.058)      │ Anguillidae (0.039) │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼─────────────────────┤
# │ Morone americana          │ Moronidae     │ Centrarchidae (0.177) │ Cyprinidae (0.133)    │ Moronidae (0.126)   │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼─────────────────────┤
# │ Salmo hucho               │ Salmonidae    │ Ictaluridae (0.392)   │ Salmonidae (0.351)    │ Gadidae (0.096)     │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼─────────────────────┤
# │ Sphyraena novaehollandiae │ Sphyraenidae  │ Sphyraenidae (0.321)  │ Engraulidae (0.197)   │ Xiphiidae (0.101)   │
# ╘═══════════════════════════╧═══════════════╧═══════════════════════╧═══════════════════════╧═════════════════════╛
#
# Top-1 Accuracy: 3/6 = 50.00%
# Top-3 Accuracy: 5/6 = 83.33%
# ==================================================
# Epoch 13/25
# ==================================================
# Step 10/79 | Loss: 0.7382 | Acc: 100.00%
# Step 20/79 | Loss: 0.7431 | Acc: 100.00%
# Step 30/79 | Loss: 0.7442 | Acc: 100.00%
# Step 40/79 | Loss: 0.7425 | Acc: 100.00%
# Step 50/79 | Loss: 0.7403 | Acc: 100.00%
# Step 60/79 | Loss: 0.7398 | Acc: 100.00%
# Step 70/79 | Loss: 0.7390 | Acc: 100.00%
#
# Epoch 13 Summary:
#   Average Loss: 0.7401
#   Training Accuracy: 100.00%
#
# ------------------------------
# EVALUATION AFTER EPOCH 13
# ------------------------------
# ╒═══════════════════════════╤═══════════════╤═══════════════════════╤═══════════════════════╤═══════════════════════╕
# │ Image                     │ True Family   │ Top-1                 │ Top-2                 │ Top-3                 │
# ╞═══════════════════════════╪═══════════════╪═══════════════════════╪═══════════════════════╪═══════════════════════╡
# │ Centropyge boylei         │ Pomacanthidae │ Pomacentridae (0.415) │ Pomacanthidae (0.176) │ Cyprinidae (0.132)    │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Electrophorus electricus  │ Gymnotidae    │ Gymnotidae (0.949)    │ Anguillidae (0.006)   │ Siluridae (0.005)     │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Gymnotus carapo           │ Gymnotidae    │ Muraenidae (0.615)    │ Esocidae (0.060)      │ Anguillidae (0.057)   │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Morone americana          │ Moronidae     │ Moronidae (0.222)     │ Cichlidae (0.127)     │ Centrarchidae (0.109) │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Salmo hucho               │ Salmonidae    │ Salmonidae (0.521)    │ Ictaluridae (0.170)   │ Esocidae (0.040)      │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Sphyraena novaehollandiae │ Sphyraenidae  │ Sphyraenidae (0.399)  │ Engraulidae (0.196)   │ Muraenidae (0.059)    │
# ╘═══════════════════════════╧═══════════════╧═══════════════════════╧═══════════════════════╧═══════════════════════╛
#
# Top-1 Accuracy: 4/6 = 66.67%
# Top-3 Accuracy: 5/6 = 83.33%
# ==================================================
# Epoch 14/25
# ==================================================
# Step 10/79 | Loss: 0.7391 | Acc: 99.38%
# Step 20/79 | Loss: 0.7462 | Acc: 99.38%
# Step 30/79 | Loss: 0.7427 | Acc: 99.58%
# Step 40/79 | Loss: 0.7403 | Acc: 99.69%
# Step 50/79 | Loss: 0.7371 | Acc: 99.75%
# Step 60/79 | Loss: 0.7366 | Acc: 99.79%
# Step 70/79 | Loss: 0.7358 | Acc: 99.82%
#
# Epoch 14 Summary:
#   Average Loss: 0.7375
#   Training Accuracy: 99.84%
#
# ------------------------------
# EVALUATION AFTER EPOCH 14
# ------------------------------
# ╒═══════════════════════════╤═══════════════╤═══════════════════════╤═══════════════════════╤═════════════════════╕
# │ Image                     │ True Family   │ Top-1                 │ Top-2                 │ Top-3               │
# ╞═══════════════════════════╪═══════════════╪═══════════════════════╪═══════════════════════╪═════════════════════╡
# │ Centropyge boylei         │ Pomacanthidae │ Pomacentridae (0.189) │ Pomacanthidae (0.179) │ Cyprinidae (0.149)  │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼─────────────────────┤
# │ Electrophorus electricus  │ Gymnotidae    │ Gymnotidae (0.945)    │ Arapaimidae (0.006)   │ Siluridae (0.005)   │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼─────────────────────┤
# │ Gymnotus carapo           │ Gymnotidae    │ Muraenidae (0.481)    │ Gobiidae (0.111)      │ Esocidae (0.073)    │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼─────────────────────┤
# │ Morone americana          │ Moronidae     │ Moronidae (0.260)     │ Cichlidae (0.164)     │ Cyprinidae (0.074)  │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼─────────────────────┤
# │ Salmo hucho               │ Salmonidae    │ Salmonidae (0.575)    │ Gadidae (0.117)       │ Ictaluridae (0.088) │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼─────────────────────┤
# │ Sphyraena novaehollandiae │ Sphyraenidae  │ Sphyraenidae (0.342)  │ Engraulidae (0.167)   │ Clupeidae (0.077)   │
# ╘═══════════════════════════╧═══════════════╧═══════════════════════╧═══════════════════════╧═════════════════════╛
#
# Top-1 Accuracy: 4/6 = 66.67%
# Top-3 Accuracy: 5/6 = 83.33%
# ==================================================
# Epoch 15/25
# ==================================================
# Step 10/79 | Loss: 0.7232 | Acc: 100.00%
# Step 20/79 | Loss: 0.7271 | Acc: 100.00%
# Step 30/79 | Loss: 0.7282 | Acc: 100.00%
# Step 40/79 | Loss: 0.7313 | Acc: 100.00%
# Step 50/79 | Loss: 0.7315 | Acc: 100.00%
# Step 60/79 | Loss: 0.7319 | Acc: 100.00%
# Step 70/79 | Loss: 0.7301 | Acc: 100.00%
#
# Epoch 15 Summary:
#   Average Loss: 0.7311
#   Training Accuracy: 100.00%
#
# ------------------------------
# EVALUATION AFTER EPOCH 15
# ------------------------------
# ╒═══════════════════════════╤═══════════════╤═══════════════════════╤═══════════════════════╤═══════════════════════╕
# │ Image                     │ True Family   │ Top-1                 │ Top-2                 │ Top-3                 │
# ╞═══════════════════════════╪═══════════════╪═══════════════════════╪═══════════════════════╪═══════════════════════╡
# │ Centropyge boylei         │ Pomacanthidae │ Pomacentridae (0.419) │ Pomacanthidae (0.134) │ Cyprinidae (0.086)    │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Electrophorus electricus  │ Gymnotidae    │ Gymnotidae (0.950)    │ Mobulidae (0.003)     │ Anguillidae (0.003)   │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Gymnotus carapo           │ Gymnotidae    │ Muraenidae (0.548)    │ Gobiidae (0.092)      │ Esocidae (0.042)      │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Morone americana          │ Moronidae     │ Moronidae (0.588)     │ Cichlidae (0.135)     │ Centrarchidae (0.044) │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Salmo hucho               │ Salmonidae    │ Salmonidae (0.282)    │ Gadidae (0.134)       │ Ictaluridae (0.112)   │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Sphyraena novaehollandiae │ Sphyraenidae  │ Sphyraenidae (0.289)  │ Engraulidae (0.210)   │ Muraenidae (0.085)    │
# ╘═══════════════════════════╧═══════════════╧═══════════════════════╧═══════════════════════╧═══════════════════════╛
#
# Top-1 Accuracy: 4/6 = 66.67%
# Top-3 Accuracy: 5/6 = 83.33%
# ==================================================
# Epoch 16/25
# ==================================================
# Step 10/79 | Loss: 0.7299 | Acc: 100.00%
# Step 20/79 | Loss: 0.7309 | Acc: 100.00%
# Step 30/79 | Loss: 0.7305 | Acc: 100.00%
# Step 40/79 | Loss: 0.7285 | Acc: 100.00%
# Step 50/79 | Loss: 0.7266 | Acc: 100.00%
# Step 60/79 | Loss: 0.7258 | Acc: 100.00%
# Step 70/79 | Loss: 0.7252 | Acc: 100.00%
#
# Epoch 16 Summary:
#   Average Loss: 0.7266
#   Training Accuracy: 99.92%
#
# ------------------------------
# EVALUATION AFTER EPOCH 16
# ------------------------------
# ╒═══════════════════════════╤═══════════════╤═══════════════════════╤═══════════════════════╤════════════════════╕
# │ Image                     │ True Family   │ Top-1                 │ Top-2                 │ Top-3              │
# ╞═══════════════════════════╪═══════════════╪═══════════════════════╪═══════════════════════╪════════════════════╡
# │ Centropyge boylei         │ Pomacanthidae │ Pomacentridae (0.299) │ Pomacanthidae (0.273) │ Cichlidae (0.050)  │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼────────────────────┤
# │ Electrophorus electricus  │ Gymnotidae    │ Gymnotidae (0.940)    │ Anguillidae (0.004)   │ Siluridae (0.004)  │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼────────────────────┤
# │ Gymnotus carapo           │ Gymnotidae    │ Muraenidae (0.331)    │ Salmonidae (0.180)    │ Gobiidae (0.104)   │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼────────────────────┤
# │ Morone americana          │ Moronidae     │ Moronidae (0.304)     │ Cichlidae (0.147)     │ Salmonidae (0.061) │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼────────────────────┤
# │ Salmo hucho               │ Salmonidae    │ Salmonidae (0.634)    │ Ictaluridae (0.142)   │ Gadidae (0.053)    │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼────────────────────┤
# │ Sphyraena novaehollandiae │ Sphyraenidae  │ Sphyraenidae (0.373)  │ Engraulidae (0.185)   │ Xiphiidae (0.070)  │
# ╘═══════════════════════════╧═══════════════╧═══════════════════════╧═══════════════════════╧════════════════════╛
#
# Top-1 Accuracy: 4/6 = 66.67%
# Top-3 Accuracy: 5/6 = 83.33%
# ==================================================
# Epoch 17/25
# ==================================================
# Step 10/79 | Loss: 0.7218 | Acc: 100.00%
# Step 20/79 | Loss: 0.7235 | Acc: 100.00%
# Step 30/79 | Loss: 0.7213 | Acc: 100.00%
# Step 40/79 | Loss: 0.7212 | Acc: 100.00%
# Step 50/79 | Loss: 0.7213 | Acc: 100.00%
# Step 60/79 | Loss: 0.7205 | Acc: 100.00%
# Step 70/79 | Loss: 0.7196 | Acc: 100.00%
#
# Epoch 17 Summary:
#   Average Loss: 0.7226
#   Training Accuracy: 99.92%
#
# ------------------------------
# EVALUATION AFTER EPOCH 17
# ------------------------------
# ╒═══════════════════════════╤═══════════════╤══════════════════════╤═══════════════════════╤═══════════════════════╕
# │ Image                     │ True Family   │ Top-1                │ Top-2                 │ Top-3                 │
# ╞═══════════════════════════╪═══════════════╪══════════════════════╪═══════════════════════╪═══════════════════════╡
# │ Centropyge boylei         │ Pomacanthidae │ Cyprinidae (0.227)   │ Pomacentridae (0.204) │ Pomacanthidae (0.152) │
# ├───────────────────────────┼───────────────┼──────────────────────┼───────────────────────┼───────────────────────┤
# │ Electrophorus electricus  │ Gymnotidae    │ Gymnotidae (0.888)   │ Cyprinidae (0.006)    │ Syngnathidae (0.006)  │
# ├───────────────────────────┼───────────────┼──────────────────────┼───────────────────────┼───────────────────────┤
# │ Gymnotus carapo           │ Gymnotidae    │ Muraenidae (0.331)   │ Salmonidae (0.147)    │ Gobiidae (0.100)      │
# ├───────────────────────────┼───────────────┼──────────────────────┼───────────────────────┼───────────────────────┤
# │ Morone americana          │ Moronidae     │ Moronidae (0.425)    │ Cichlidae (0.130)     │ Centrarchidae (0.089) │
# ├───────────────────────────┼───────────────┼──────────────────────┼───────────────────────┼───────────────────────┤
# │ Salmo hucho               │ Salmonidae    │ Salmonidae (0.728)   │ Gadidae (0.060)       │ Ictaluridae (0.048)   │
# ├───────────────────────────┼───────────────┼──────────────────────┼───────────────────────┼───────────────────────┤
# │ Sphyraena novaehollandiae │ Sphyraenidae  │ Sphyraenidae (0.412) │ Engraulidae (0.125)   │ Xiphiidae (0.065)     │
# ╘═══════════════════════════╧═══════════════╧══════════════════════╧═══════════════════════╧═══════════════════════╛
#
# Top-1 Accuracy: 4/6 = 66.67%
# Top-3 Accuracy: 5/6 = 83.33%
# ==================================================
# Epoch 18/25
# ==================================================
# Step 10/79 | Loss: 0.7224 | Acc: 100.00%
# Step 20/79 | Loss: 0.7203 | Acc: 100.00%
# Step 30/79 | Loss: 0.7220 | Acc: 100.00%
# Step 40/79 | Loss: 0.7254 | Acc: 99.84%
# Step 50/79 | Loss: 0.7250 | Acc: 99.75%
# Step 60/79 | Loss: 0.7236 | Acc: 99.79%
# Step 70/79 | Loss: 0.7227 | Acc: 99.82%
#
# Epoch 18 Summary:
#   Average Loss: 0.7241
#   Training Accuracy: 99.76%
#
# ------------------------------
# EVALUATION AFTER EPOCH 18
# ------------------------------
# ╒═══════════════════════════╤═══════════════╤═════════════════════╤═══════════════════════╤════════════════════════╕
# │ Image                     │ True Family   │ Top-1               │ Top-2                 │ Top-3                  │
# ╞═══════════════════════════╪═══════════════╪═════════════════════╪═══════════════════════╪════════════════════════╡
# │ Centropyge boylei         │ Pomacanthidae │ Cyprinidae (0.286)  │ Pomacanthidae (0.164) │ Pomacentridae (0.156)  │
# ├───────────────────────────┼───────────────┼─────────────────────┼───────────────────────┼────────────────────────┤
# │ Electrophorus electricus  │ Gymnotidae    │ Gymnotidae (0.938)  │ Arapaimidae (0.003)   │ Osteoglossidae (0.003) │
# ├───────────────────────────┼───────────────┼─────────────────────┼───────────────────────┼────────────────────────┤
# │ Gymnotus carapo           │ Gymnotidae    │ Muraenidae (0.240)  │ Salmonidae (0.180)    │ Esocidae (0.139)       │
# ├───────────────────────────┼───────────────┼─────────────────────┼───────────────────────┼────────────────────────┤
# │ Morone americana          │ Moronidae     │ Moronidae (0.301)   │ Centrarchidae (0.098) │ Cyprinidae (0.096)     │
# ├───────────────────────────┼───────────────┼─────────────────────┼───────────────────────┼────────────────────────┤
# │ Salmo hucho               │ Salmonidae    │ Salmonidae (0.815)  │ Gadidae (0.033)       │ Ictaluridae (0.029)    │
# ├───────────────────────────┼───────────────┼─────────────────────┼───────────────────────┼────────────────────────┤
# │ Sphyraena novaehollandiae │ Sphyraenidae  │ Engraulidae (0.317) │ Sphyraenidae (0.193)  │ Muraenidae (0.071)     │
# ╘═══════════════════════════╧═══════════════╧═════════════════════╧═══════════════════════╧════════════════════════╛
#
# Top-1 Accuracy: 3/6 = 50.00%
# Top-3 Accuracy: 5/6 = 83.33%
# ==================================================
# Epoch 19/25
# ==================================================
# Step 10/79 | Loss: 0.7215 | Acc: 100.00%
# Step 20/79 | Loss: 0.7185 | Acc: 100.00%
# Step 30/79 | Loss: 0.7159 | Acc: 100.00%
# Step 40/79 | Loss: 0.7165 | Acc: 100.00%
# Step 50/79 | Loss: 0.7186 | Acc: 100.00%
# Step 60/79 | Loss: 0.7189 | Acc: 100.00%
# Step 70/79 | Loss: 0.7189 | Acc: 100.00%
#
# Epoch 19 Summary:
#   Average Loss: 0.7205
#   Training Accuracy: 100.00%
#
# ------------------------------
# EVALUATION AFTER EPOCH 19
# ------------------------------
# ╒═══════════════════════════╤═══════════════╤═══════════════════════╤═══════════════════════╤══════════════════════╕
# │ Image                     │ True Family   │ Top-1                 │ Top-2                 │ Top-3                │
# ╞═══════════════════════════╪═══════════════╪═══════════════════════╪═══════════════════════╪══════════════════════╡
# │ Centropyge boylei         │ Pomacanthidae │ Pomacanthidae (0.235) │ Cyprinidae (0.198)    │ Cichlidae (0.155)    │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼──────────────────────┤
# │ Electrophorus electricus  │ Gymnotidae    │ Gymnotidae (0.919)    │ Anguillidae (0.005)   │ Siluridae (0.004)    │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼──────────────────────┤
# │ Gymnotus carapo           │ Gymnotidae    │ Muraenidae (0.254)    │ Salmonidae (0.160)    │ Gobiidae (0.128)     │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼──────────────────────┤
# │ Morone americana          │ Moronidae     │ Moronidae (0.730)     │ Centrarchidae (0.058) │ Cichlidae (0.033)    │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼──────────────────────┤
# │ Salmo hucho               │ Salmonidae    │ Salmonidae (0.896)    │ Ictaluridae (0.024)   │ Esocidae (0.012)     │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼──────────────────────┤
# │ Sphyraena novaehollandiae │ Sphyraenidae  │ Engraulidae (0.347)   │ Clupeidae (0.113)     │ Sphyraenidae (0.113) │
# ╘═══════════════════════════╧═══════════════╧═══════════════════════╧═══════════════════════╧══════════════════════╛
#
# Top-1 Accuracy: 4/6 = 66.67%
# Top-3 Accuracy: 5/6 = 83.33%
# ==================================================
# Epoch 20/25
# ==================================================
# Step 10/79 | Loss: 0.7155 | Acc: 100.00%
# Step 20/79 | Loss: 0.7162 | Acc: 100.00%
# Step 30/79 | Loss: 0.7156 | Acc: 100.00%
# Step 40/79 | Loss: 0.7160 | Acc: 100.00%
# Step 50/79 | Loss: 0.7191 | Acc: 99.75%
# Step 60/79 | Loss: 0.7192 | Acc: 99.79%
# Step 70/79 | Loss: 0.7180 | Acc: 99.82%
#
# Epoch 20 Summary:
#   Average Loss: 0.7187
#   Training Accuracy: 99.84%
#
# ------------------------------
# EVALUATION AFTER EPOCH 20
# ------------------------------
# ╒═══════════════════════════╤═══════════════╤═══════════════════════╤═══════════════════════╤═══════════════════════╕
# │ Image                     │ True Family   │ Top-1                 │ Top-2                 │ Top-3                 │
# ╞═══════════════════════════╪═══════════════╪═══════════════════════╪═══════════════════════╪═══════════════════════╡
# │ Centropyge boylei         │ Pomacanthidae │ Pomacentridae (0.458) │ Cyprinidae (0.192)    │ Pomacanthidae (0.062) │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Electrophorus electricus  │ Gymnotidae    │ Gymnotidae (0.932)    │ Siluridae (0.003)     │ Anguillidae (0.003)   │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Gymnotus carapo           │ Gymnotidae    │ Muraenidae (0.537)    │ Salmonidae (0.093)    │ Gobiidae (0.085)      │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Morone americana          │ Moronidae     │ Moronidae (0.745)     │ Centrarchidae (0.075) │ Cichlidae (0.018)     │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Salmo hucho               │ Salmonidae    │ Salmonidae (0.832)    │ Ictaluridae (0.040)   │ Gadidae (0.026)       │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Sphyraena novaehollandiae │ Sphyraenidae  │ Engraulidae (0.273)   │ Sphyraenidae (0.131)  │ Muraenidae (0.123)    │
# ╘═══════════════════════════╧═══════════════╧═══════════════════════╧═══════════════════════╧═══════════════════════╛
#
# Top-1 Accuracy: 3/6 = 50.00%
# Top-3 Accuracy: 5/6 = 83.33%
# ==================================================
# Epoch 21/25
# ==================================================
# Step 10/79 | Loss: 0.7119 | Acc: 100.00%
# Step 20/79 | Loss: 0.7106 | Acc: 100.00%
# Step 30/79 | Loss: 0.7115 | Acc: 100.00%
# Step 40/79 | Loss: 0.7141 | Acc: 100.00%
# Step 50/79 | Loss: 0.7144 | Acc: 100.00%
# Step 60/79 | Loss: 0.7143 | Acc: 100.00%
# Step 70/79 | Loss: 0.7140 | Acc: 100.00%
#
# Epoch 21 Summary:
#   Average Loss: 0.7152
#   Training Accuracy: 100.00%
#
# ------------------------------
# EVALUATION AFTER EPOCH 21
# ------------------------------
# ╒═══════════════════════════╤═══════════════╤═══════════════════════╤═══════════════════════╤═══════════════════════╕
# │ Image                     │ True Family   │ Top-1                 │ Top-2                 │ Top-3                 │
# ╞═══════════════════════════╪═══════════════╪═══════════════════════╪═══════════════════════╪═══════════════════════╡
# │ Centropyge boylei         │ Pomacanthidae │ Pomacanthidae (0.220) │ Cyprinidae (0.208)    │ Pomacentridae (0.197) │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Electrophorus electricus  │ Gymnotidae    │ Gymnotidae (0.940)    │ Mobulidae (0.003)     │ Anguillidae (0.003)   │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Gymnotus carapo           │ Gymnotidae    │ Muraenidae (0.545)    │ Esocidae (0.098)      │ Gobiidae (0.086)      │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Morone americana          │ Moronidae     │ Moronidae (0.717)     │ Centrarchidae (0.071) │ Cichlidae (0.024)     │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Salmo hucho               │ Salmonidae    │ Salmonidae (0.783)    │ Ictaluridae (0.064)   │ Esocidae (0.025)      │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Sphyraena novaehollandiae │ Sphyraenidae  │ Engraulidae (0.257)   │ Sphyraenidae (0.171)  │ Muraenidae (0.084)    │
# ╘═══════════════════════════╧═══════════════╧═══════════════════════╧═══════════════════════╧═══════════════════════╛
#
# Top-1 Accuracy: 4/6 = 66.67%
# Top-3 Accuracy: 5/6 = 83.33%
# ==================================================
# Epoch 22/25
# ==================================================
# Step 10/79 | Loss: 0.7123 | Acc: 100.00%
# Step 20/79 | Loss: 0.7101 | Acc: 100.00%
# Step 30/79 | Loss: 0.7095 | Acc: 100.00%
# Step 40/79 | Loss: 0.7096 | Acc: 100.00%
# Step 50/79 | Loss: 0.7121 | Acc: 99.88%
# Step 60/79 | Loss: 0.7120 | Acc: 99.90%
# Step 70/79 | Loss: 0.7115 | Acc: 99.91%
#
# Epoch 22 Summary:
#   Average Loss: 0.7134
#   Training Accuracy: 99.92%
#
# ------------------------------
# EVALUATION AFTER EPOCH 22
# ------------------------------
# ╒═══════════════════════════╤═══════════════╤═══════════════════════╤═══════════════════════╤════════════════════════╕
# │ Image                     │ True Family   │ Top-1                 │ Top-2                 │ Top-3                  │
# ╞═══════════════════════════╪═══════════════╪═══════════════════════╪═══════════════════════╪════════════════════════╡
# │ Centropyge boylei         │ Pomacanthidae │ Pomacentridae (0.406) │ Pomacanthidae (0.125) │ Cichlidae (0.123)      │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼────────────────────────┤
# │ Electrophorus electricus  │ Gymnotidae    │ Gymnotidae (0.924)    │ Mobulidae (0.004)     │ Osteoglossidae (0.004) │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼────────────────────────┤
# │ Gymnotus carapo           │ Gymnotidae    │ Muraenidae (0.615)    │ Gobiidae (0.085)      │ Esocidae (0.074)       │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼────────────────────────┤
# │ Morone americana          │ Moronidae     │ Moronidae (0.435)     │ Centrarchidae (0.107) │ Cichlidae (0.106)      │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼────────────────────────┤
# │ Salmo hucho               │ Salmonidae    │ Salmonidae (0.558)    │ Ictaluridae (0.101)   │ Esocidae (0.048)       │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼────────────────────────┤
# │ Sphyraena novaehollandiae │ Sphyraenidae  │ Engraulidae (0.430)   │ Muraenidae (0.079)    │ Sphyraenidae (0.076)   │
# ╘═══════════════════════════╧═══════════════╧═══════════════════════╧═══════════════════════╧════════════════════════╛
#
# Top-1 Accuracy: 3/6 = 50.00%
# Top-3 Accuracy: 5/6 = 83.33%
# ==================================================
# Epoch 23/25
# ==================================================
# Step 10/79 | Loss: 0.7156 | Acc: 100.00%
# Step 20/79 | Loss: 0.7117 | Acc: 100.00%
# Step 30/79 | Loss: 0.7114 | Acc: 100.00%
# Step 40/79 | Loss: 0.7129 | Acc: 100.00%
# Step 50/79 | Loss: 0.7128 | Acc: 100.00%
# Step 60/79 | Loss: 0.7124 | Acc: 100.00%
# Step 70/79 | Loss: 0.7116 | Acc: 100.00%
#
# Epoch 23 Summary:
#   Average Loss: 0.7139
#   Training Accuracy: 99.92%
#
# ------------------------------
# EVALUATION AFTER EPOCH 23
# ------------------------------
# ╒═══════════════════════════╤═══════════════╤═══════════════════════╤═══════════════════════╤════════════════════════╕
# │ Image                     │ True Family   │ Top-1                 │ Top-2                 │ Top-3                  │
# ╞═══════════════════════════╪═══════════════╪═══════════════════════╪═══════════════════════╪════════════════════════╡
# │ Centropyge boylei         │ Pomacanthidae │ Pomacentridae (0.358) │ Pomacanthidae (0.137) │ Cyprinidae (0.135)     │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼────────────────────────┤
# │ Electrophorus electricus  │ Gymnotidae    │ Gymnotidae (0.929)    │ Mobulidae (0.004)     │ Osteoglossidae (0.003) │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼────────────────────────┤
# │ Gymnotus carapo           │ Gymnotidae    │ Muraenidae (0.349)    │ Gobiidae (0.131)      │ Esocidae (0.111)       │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼────────────────────────┤
# │ Morone americana          │ Moronidae     │ Moronidae (0.682)     │ Cichlidae (0.057)     │ Centrarchidae (0.052)  │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼────────────────────────┤
# │ Salmo hucho               │ Salmonidae    │ Salmonidae (0.600)    │ Ictaluridae (0.122)   │ Gadidae (0.054)        │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼────────────────────────┤
# │ Sphyraena novaehollandiae │ Sphyraenidae  │ Engraulidae (0.305)   │ Sphyraenidae (0.149)  │ Characidae (0.099)     │
# ╘═══════════════════════════╧═══════════════╧═══════════════════════╧═══════════════════════╧════════════════════════╛
#
# Top-1 Accuracy: 3/6 = 50.00%
# Top-3 Accuracy: 5/6 = 83.33%
# ==================================================
# Epoch 24/25
# ==================================================
# Step 10/79 | Loss: 0.7105 | Acc: 100.00%
# Step 20/79 | Loss: 0.7117 | Acc: 100.00%
# Step 30/79 | Loss: 0.7108 | Acc: 100.00%
# Step 40/79 | Loss: 0.7115 | Acc: 100.00%
# Step 50/79 | Loss: 0.7114 | Acc: 100.00%
# Step 60/79 | Loss: 0.7110 | Acc: 100.00%
# Step 70/79 | Loss: 0.7109 | Acc: 100.00%
#
# Epoch 24 Summary:
#   Average Loss: 0.7125
#   Training Accuracy: 100.00%
#
# ------------------------------
# EVALUATION AFTER EPOCH 24
# ------------------------------
# ╒═══════════════════════════╤═══════════════╤═══════════════════════╤═══════════════════════╤═══════════════════════╕
# │ Image                     │ True Family   │ Top-1                 │ Top-2                 │ Top-3                 │
# ╞═══════════════════════════╪═══════════════╪═══════════════════════╪═══════════════════════╪═══════════════════════╡
# │ Centropyge boylei         │ Pomacanthidae │ Pomacentridae (0.373) │ Cyprinidae (0.194)    │ Pomacanthidae (0.115) │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Electrophorus electricus  │ Gymnotidae    │ Gymnotidae (0.919)    │ Mobulidae (0.004)     │ Siluridae (0.004)     │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Gymnotus carapo           │ Gymnotidae    │ Salmonidae (0.219)    │ Muraenidae (0.164)    │ Gobiidae (0.113)      │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Morone americana          │ Moronidae     │ Moronidae (0.689)     │ Centrarchidae (0.087) │ Cichlidae (0.036)     │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Salmo hucho               │ Salmonidae    │ Salmonidae (0.903)    │ Ictaluridae (0.024)   │ Esocidae (0.006)      │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼───────────────────────┤
# │ Sphyraena novaehollandiae │ Sphyraenidae  │ Engraulidae (0.291)   │ Characidae (0.169)    │ Xiphiidae (0.096)     │
# ╘═══════════════════════════╧═══════════════╧═══════════════════════╧═══════════════════════╧═══════════════════════╛
#
# Top-1 Accuracy: 3/6 = 50.00%
# Top-3 Accuracy: 4/6 = 66.67%
# ==================================================
# Epoch 25/25
# ==================================================
# Step 10/79 | Loss: 0.7071 | Acc: 100.00%
# Step 20/79 | Loss: 0.7091 | Acc: 100.00%
# Step 30/79 | Loss: 0.7109 | Acc: 100.00%
# Step 40/79 | Loss: 0.7124 | Acc: 100.00%
# Step 50/79 | Loss: 0.7122 | Acc: 100.00%
# Step 60/79 | Loss: 0.7112 | Acc: 100.00%
# Step 70/79 | Loss: 0.7113 | Acc: 100.00%
#
# Epoch 25 Summary:
#   Average Loss: 0.7126
#   Training Accuracy: 100.00%
#
# ------------------------------
# EVALUATION AFTER EPOCH 25
# ------------------------------
# ╒═══════════════════════════╤═══════════════╤═══════════════════════╤═══════════════════════╤═════════════════════╕
# │ Image                     │ True Family   │ Top-1                 │ Top-2                 │ Top-3               │
# ╞═══════════════════════════╪═══════════════╪═══════════════════════╪═══════════════════════╪═════════════════════╡
# │ Centropyge boylei         │ Pomacanthidae │ Pomacentridae (0.364) │ Pomacanthidae (0.196) │ Cichlidae (0.087)   │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼─────────────────────┤
# │ Electrophorus electricus  │ Gymnotidae    │ Gymnotidae (0.931)    │ Mobulidae (0.004)     │ Anguillidae (0.004) │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼─────────────────────┤
# │ Gymnotus carapo           │ Gymnotidae    │ Muraenidae (0.472)    │ Salmonidae (0.110)    │ Gobiidae (0.080)    │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼─────────────────────┤
# │ Morone americana          │ Moronidae     │ Moronidae (0.827)     │ Centrarchidae (0.033) │ Cichlidae (0.020)   │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼─────────────────────┤
# │ Salmo hucho               │ Salmonidae    │ Salmonidae (0.898)    │ Ictaluridae (0.026)   │ Gadidae (0.006)     │
# ├───────────────────────────┼───────────────┼───────────────────────┼───────────────────────┼─────────────────────┤
# │ Sphyraena novaehollandiae │ Sphyraenidae  │ Engraulidae (0.412)   │ Sphyraenidae (0.089)  │ Characidae (0.078)  │
# ╘═══════════════════════════╧═══════════════╧═══════════════════════╧═══════════════════════╧═════════════════════╛
#
# Top-1 Accuracy: 3/6 = 50.00%
# Top-3 Accuracy: 5/6 = 83.33%
# ==============================
# TRAINING COMPLETE
# ==============================
